# %% [markdown]
# This cell initializes spaCy for NLP tasks and loads the RoBERTa model and tokenizer for embeddings. Additionally, it loads and samples 90,000 sentences from a Yelp dataset for pre-training.

# %%
import spacy
import torch
import pandas as pd
import pickle
import os
from torch_geometric.loader import DataLoader
from torch_geometric.data import Data
from transformers import AutoTokenizer, AutoModel
import pytorch_lightning as pl
from torch_geometric.nn import GCNConv
import random
import numpy as np
import warnings

os.environ["CUDA_LAUNCH_BLOCKING"] = "1"

warnings.filterwarnings("ignore", category=UserWarning, module="torch_geometric.data.collate")
warnings.filterwarnings("ignore", category=UserWarning, module="torch.nn.modules.loss")

os.environ["TOKENIZERS_PARALLELISM"] = "false"
try:
    torch.manual_seed(42)
    np.random.seed(42)
    random.seed(42)
    print("Random seeds set successfully.")
except Exception as e:
    print(f"Error setting random seeds: {e}")
    exit()
torch.set_float32_matmul_precision('medium')

try:
    torch.cuda.empty_cache()
    print("GPU memory cleared successfully.")
except Exception as e:
    print(f"Error clearing GPU memory: {e}")

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
if torch.cuda.is_available():
    torch.cuda.set_device(0)
    print(f"Using GPU: {torch.cuda.get_device_name(0)}")
    print(f"PyTorch CUDA version: {torch.version.cuda}")
    print(f"Number of CUDA devices: {torch.cuda.device_count()}")
else:
    print("CUDA not available. Exiting.")
    exit()
os.makedirs('data', exist_ok=True)
print("Ensured data/ directory exists")

print("PyTorch Lightning version:", pl.__version__)

try:
    nlp = spacy.load('en_core_web_sm', disable=['ner', 'lemmatizer'])
    tokenizer = AutoTokenizer.from_pretrained('roberta-base')
    roberta_model = AutoModel.from_pretrained('roberta-base').to(device)
    print(f"RoBERTa model loaded successfully on {device}.")
except Exception as e:
    print(f"Failed to load spaCy or RoBERTa: {e}")
    exit()

try:
    sentences_df = pd.read_csv('data/yelp_restaurant_sentences.csv')
    sentences_df = sentences_df[sentences_df['sentence'].notna() & (sentences_df['sentence'].str.strip() != '')]
    sentences_df = sentences_df.sample(n=90000, random_state=42)
    print(f"Sampled {len(sentences_df)} sentences for pre-training")
    if sentences_df.empty:
        raise ValueError("No valid sentences found after cleaning.")
except FileNotFoundError:
    print("Dataset file not found. Ensure 'data/yelp_restaurant_sentences.csv' exists.")
    exit()

# %% [markdown]
# This cell processes the sampled sentences using spaCy to extract unique dependency types (e.g., nsubj, dobj) and creates a mapping of dependency types to indices. The results are saved to a pickle file for later use in graph construction.

# %%
dep_types = set()
for doc in nlp.pipe(sentences_df['sentence'].tolist(), batch_size=32):
    for token in doc:
        if token.head != token:
            dep_types.add(token.dep_)
dep_type_to_idx = {dep: idx for idx, dep in enumerate(sorted(dep_types))}
print(f"Found {len(dep_types)} dependency types")

with open('data/dep_types.pkl', 'wb') as f:
    pickle.dump({'dep_types': dep_types, 'dep_type_to_idx': dep_type_to_idx}, f)
# Out:
# Random seeds set successfully.
# GPU memory cleared successfully.
# Using GPU: NVIDIA L40S
# PyTorch CUDA version: 11.7
# Number of CUDA devices: 1
# Ensured data/ directory exists
# PyTorch Lightning version: 2.0.0
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/huggingface_hub/file_download.py:896: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/481 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# pytorch_model.bin:   0%|          | 0.00/501M [00:00<?, ?B/s]
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# RoBERTa model loaded successfully on cuda.
# Sampled 90000 sentences for pre-training

# %% [markdown]
# This cell defines a function create_dependency_graph that constructs dependency graphs for the ARGCN model. It processes sentences to create graph structures with nodes (tokens), edges (dependency relations), and edge attributes (dependency types). It also identifies noun and adjective indices for later use in pre-training tasks

# %%
def create_dependency_graph(sentences, num_nodes_list):
    graphs = []
    for doc, sent, num_nodes in zip(nlp.pipe(sentences, batch_size=32), sentences, num_nodes_list):
        nodes = [token.text.lower() for token in doc][:num_nodes]
        edges = []
        edge_types = []
        for token in doc:
            if token.head != token and token.i < num_nodes and token.head.i < num_nodes:
                edges.append([token.i, token.head.i])
                edge_types.append(dep_type_to_idx.get(token.dep_, 0))
        edge_index = torch.tensor(edges, dtype=torch.long).t().contiguous() if edges else torch.empty((2, 0), dtype=torch.long)
        edge_types = torch.tensor(edge_types, dtype=torch.long) if edge_types else torch.empty((0,), dtype=torch.long)
        noun_indices = [i for i, token in enumerate(doc) if token.pos_ == 'NOUN' and i < num_nodes]
        adj_indices = [i for i, token in enumerate(doc) if token.pos_ == 'ADJ' and i < num_nodes]
        if edges and edge_index.max().item() >= num_nodes:
            print(f"Warning: Invalid edge_index in dependency graph for sentence '{sent}': max index {edge_index.max().item()}, num_nodes {num_nodes}")
            continue
        graph = Data(edge_index=edge_index, edge_attr=edge_types, sentence=sent, nodes=nodes, noun_indices=noun_indices, adj_indices=adj_indices)
        graphs.append(graph)
    return graphs

# %% [markdown]
# This cell defines a function create_contextual_graph that constructs contextual graphs for the T-GCN model based on co-occurrence within a window of tokens. It creates graph structures with nodes and edges representing token proximity, and identifies noun and adjective indices.

# %%
def create_contextual_graph(sentences, num_nodes_list):
    graphs = []
    for doc, sent, num_nodes in zip(nlp.pipe(sentences, batch_size=32), sentences, num_nodes_list):
        nodes = [token.text.lower() for token in doc][:num_nodes]
        edges = []
        window = 2
        for i in range(num_nodes):
            for j in range(max(0, i - window), min(num_nodes, i + window + 1)):
                if i != j:
                    edges.append([i, j])
        edge_index = torch.tensor(edges, dtype=torch.long).t().contiguous() if edges else torch.empty((2, 0), dtype=torch.long)
        noun_indices = [i for i, token in enumerate(doc) if token.pos_ == 'NOUN' and i < num_nodes]
        adj_indices = [i for i, token in enumerate(doc) if token.pos_ == 'ADJ' and i < num_nodes]
        if edges and edge_index.max().item() >= num_nodes:
            print(f"Warning: Invalid edge_index in contextual graph for sentence '{sent}': max index {edge_index.max().item()}, num_nodes {num_nodes}")
            continue
        graph = Data(edge_index=edge_index, sentence=sent, nodes=nodes, noun_indices=noun_indices, adj_indices=adj_indices)
        graphs.append(graph)
    return graphs

# %% [markdown]
# This cell defines a function get_roberta_embeddings to generate RoBERTa embeddings for sentences. It processes sentences in batches, creates dependency and contextual graphs, assigns embeddings to graph nodes, and saves the graphs with metadata (user_id, date). It validates the graphs and prints progress.

# %%
def get_roberta_embeddings(sentences, nodes_list):
    valid_sentences = []
    valid_nodes = []
    valid_indices = []
    for i, (sent, nodes) in enumerate(zip(sentences, nodes_list)):
        if isinstance(sent, str) and sent.strip() and nodes:
            valid_sentences.append(sent)
            valid_nodes.append(nodes)
            valid_indices.append(i)
    print(f"Batch - Total sentences: {len(sentences)}, Valid sentences: {len(valid_sentences)}")
    if not valid_sentences:
        return []
    try:
        inputs = tokenizer(valid_sentences, return_tensors='pt', padding=True, truncation=True, max_length=512)
        inputs = {k: v.to(device) for k, v in inputs.items()}
        with torch.no_grad():
            outputs = roberta_model(**inputs)
        embeddings = outputs.last_hidden_state.cpu()
        batched_embeddings = []
        for i, nodes in enumerate(valid_nodes):
            num_nodes = min(len(nodes), embeddings[i].shape[0] - 2)  
            if num_nodes == 0:
                print(f"Warning: No valid nodes for sentence {valid_sentences[i]}")
                continue
            emb = embeddings[i, 1:num_nodes+1].clone()
            batched_embeddings.append((valid_indices[i], emb, nodes[:num_nodes], num_nodes))
        return batched_embeddings
    except RuntimeError as e:
        print(f"Error in RoBERTa embeddings: {e}")
        return []


batch_size = 32
dep_graphs = [] 
context_graphs = [] 
for start_idx in range(0, len(sentences_df), batch_size):
    batch_df = sentences_df.iloc[start_idx:min(start_idx + batch_size, len(sentences_df))]
    batch_sentences = batch_df['sentence'].tolist()

    batch_nodes = [[token.text.lower() for token in nlp(sent)] for sent in batch_sentences]
    batch_embeddings = get_roberta_embeddings(batch_sentences, batch_nodes)
    embedding_dict = {idx: (emb, nodes, num_nodes) for idx, emb, nodes, num_nodes in batch_embeddings}
    print(f"Batch {start_idx//batch_size + 1} - Embedding dict size: {len(embedding_dict)}")
   
    batch_num_nodes = [embedding_dict.get(i, (None, None, 0))[2] for i in range(len(batch_sentences))]
    batch_dep_graphs = create_dependency_graph(batch_sentences, batch_num_nodes)
    batch_context_graphs = create_contextual_graph(batch_sentences, batch_num_nodes)
    

    for i, (row, dep_graph, context_graph) in enumerate(zip(batch_df.itertuples(), batch_dep_graphs, batch_context_graphs)):
        idx = i
        if idx in embedding_dict:
            emb, adjusted_nodes, num_nodes = embedding_dict[idx]
            dep_graph.x = emb
            context_graph.x = emb
            dep_graph.nodes = adjusted_nodes
            context_graph.nodes = adjusted_nodes
            dep_graph.user_id = row.user_id
            dep_graph.date = row.date
            context_graph.user_id = row.user_id
            context_graph.date = row.date
            dep_graphs.append(dep_graph)
            context_graphs.append(context_graph)
    print(f"Batch {start_idx//batch_size + 1} - Total graphs: {len(dep_graphs)}")

if not dep_graphs or not context_graphs:
    raise ValueError("No graphs created. Check dataset and embedding generation.")
print(f"Total dependency graphs created: {len(dep_graphs)}")
print(f"Total contextual graphs created: {len(context_graphs)}")

# %% [markdown]
# This cell defines a function is_valid_graph to check if a graph is valid for training. It ensures node features, edge indices, edge attributes, and labels (if present) are free of NaN, infinite values, or index errors.

# %%
def is_valid_graph(graph):
    """Check if a graph is valid for training (no NaN, Inf, or index issues)."""
    try:

        if graph.x is not None:
            if not torch.isfinite(graph.x).all():
                return False
            if torch.isnan(graph.x).any():
                return False
        
        if graph.edge_index is not None:
            if not torch.isfinite(graph.edge_index).all():
                return False
            if torch.isnan(graph.edge_index).any():
                return False

            if graph.edge_index.max() >= graph.num_nodes:
                return False
        

        if hasattr(graph, 'edge_attr') and graph.edge_attr is not None:
            if not torch.isfinite(graph.edge_attr).all():
                return False
            if torch.isnan(graph.edge_attr).any():
                return False
        

        if hasattr(graph, 'y') and graph.y is not None:
            if not torch.isfinite(graph.y).all():
                return False
            if torch.isnan(graph.y).any():
                return False
        
        return True
    except Exception:
        return False

# %% [markdown]
# This cell loads previously saved dependency and contextual graphs, validates them using is_valid_graph, and saves the valid graphs to new pickle files. It ensures no mismatch in graph counts and handles errors.

# %%
try:
    
    with open('data/yelp_restaurant_dep_graphs_embedded.pkl', 'rb') as f:
        dep_graphs = pickle.load(f)
    
   
    with open('data/yelp_restaurant_context_graphs_embedded.pkl', 'rb') as f:
        context_graphs = pickle.load(f)
    
    total_loaded = len(dep_graphs)
    print(f"Loaded {len(dep_graphs)} dependency graphs and {len(context_graphs)} context graphs.")
    
   
    if len(dep_graphs) != len(context_graphs):
        raise ValueError("Mismatch between number of dependency and context graphs.")
    
 
    valid_dep_graphs = []
    valid_context_graphs = []
    for dep_g, ctx_g in zip(dep_graphs, context_graphs):
        if is_valid_graph(dep_g) and is_valid_graph(ctx_g):
            valid_dep_graphs.append(dep_g)
            valid_context_graphs.append(ctx_g)
    
    num_valid = len(valid_dep_graphs)
    print(f"Retained {num_valid} valid dependency graphs and {len(valid_context_graphs)} valid context graphs after validation.")
    print(f"Valid graphs: {num_valid} out of {total_loaded} loaded ({num_valid/total_loaded*100:.2f}%).")
    

    if len(valid_dep_graphs) != len(valid_context_graphs):
        raise ValueError("Mismatch in valid graphs after filtering.")
    
    if len(valid_dep_graphs) == 0:
        raise ValueError("No valid graphs found after filtering.")
    
    with open('data/yelp_restaurant_dep_graphs_valid.pkl', 'wb') as f:
        pickle.dump(valid_dep_graphs, f)
    with open('data/yelp_restaurant_context_graphs_valid.pkl', 'wb') as f:
        pickle.dump(valid_context_graphs, f)
    print("Valid graphs saved to 'data/yelp_restaurant_dep_graphs_valid.pkl' and 'data/yelp_restaurant_context_graphs_valid.pkl'.")

except FileNotFoundError as e:
    print(f"Graph files not found: {e}. Ensure 'data/yelp_restaurant_dep_graphs_embedded.pkl' and 'data/yelp_restaurant_context_graphs_embedded.pkl' exist.")
    exit()
except Exception as e:
    print(f"An error occurred: {e}")
    exit()
# Out:
# Loaded 90000 dependency graphs and 90000 context graphs.
# Retained 89997 valid dependency graphs and 89997 valid context graphs after validation.
# Valid graphs: 89997 out of 90000 loaded (100.00%).
# Valid graphs saved to 'data/yelp_restaurant_dep_graphs_valid.pkl' and 'data/yelp_restaurant_context_graphs_valid.pkl'.

# %%
import pickle
import torch
import numpy as np
from torch_geometric.data import Data

# %% [markdown]
# This cell loads the validated dependency and contextual graphs from pickle files and checks for consistency in graph counts. It handles errors if files are missing or loading fails.

# %%
try:
   
    with open('data/yelp_restaurant_dep_graphs_valid.pkl', 'rb') as f:
        dep_graphs = pickle.load(f)
    
    with open('data/yelp_restaurant_context_graphs_valid.pkl', 'rb') as f:
        context_graphs = pickle.load(f)
    
    print(f"Loaded {len(dep_graphs)} valid dependency graphs and {len(context_graphs)} valid context graphs.")
    
    if len(dep_graphs) != len(context_graphs):
        raise ValueError("Mismatch between number of valid dependency and context graphs.")

except FileNotFoundError as e:
    print(f"Valid graph files not found: {e}. Ensure 'data/yelp_restaurant_dep_graphs_valid.pkl' and 'data/yelp_restaurant_context_graphs_valid.pkl' exist.")
    exit()
except Exception as e:
    print(f"An error occurred while loading valid graphs: {e}")
    exit()
# Out:
# Loaded 89997 valid dependency graphs and 89997 valid context graphs.

# %% [markdown]
# This cell sets up the environment, loads dependency types and all valid graph pairs from pickle files, and trains a `HybridGCN` model combining T-GCN (contextual) and ARGCN (dependency) for pre-training. It performs two tasks: predicting opinion word embeddings and dependency types, logs losses, and saves the trained model checkpoint.

# %%
try:
    with open('data/yelp_restaurant_dep_graphs_valid.pkl', 'rb') as f:
        dep_graphs = pickle.load(f)
    with open('data/yelp_restaurant_context_graphs_valid.pkl', 'rb') as f:
        context_graphs = pickle.load(f)
    
    print(f"Loaded {len(dep_graphs)} dependency graphs and {len(context_graphs)} context graphs.")

    if len(dep_graphs) != len(context_graphs):
        raise ValueError("Mismatch between number of dependency and context graphs.")
   
    valid_dep_graphs = []
    valid_context_graphs = []
    for idx in range(len(dep_graphs)):
        if is_valid_graph(dep_graphs[idx]) and is_valid_graph(context_graphs[idx]):
            valid_dep_graphs.append(dep_graphs[idx])
            valid_context_graphs.append(context_graphs[idx])
            print(f"Graph pair {idx}: Valid")
        else:
            print(f"Skipping graph pair {idx} due to invalid data.")
    
    num_valid = len(valid_dep_graphs)
    print(f"Selected {num_valid} valid dependency graphs and {len(valid_context_graphs)} valid context graphs.")
    
    if num_valid == 0:
        raise ValueError("No valid graph pairs found.")
    
    with open('data/yelp_restaurant_dep_graph_valid.pkl', 'wb') as f:
        pickle.dump(valid_dep_graphs, f)
    with open('data/yelp_restaurant_context_graph_valid.pkl', 'wb') as f:
        pickle.dump(valid_context_graphs, f)
    print("Saved all valid graph pairs to 'data/yelp_restaurant_dep_graph_valid.pkl' and 'data/yelp_restaurant_context_graph_valid.pkl'.")

except FileNotFoundError as e:
    print(f"Graph files not found: {e}. Ensure 'data/yelp_restaurant_dep_graphs_valid.pkl' and 'data/yelp_restaurant_context_graphs_valid.pkl' exist.")
    exit()
except Exception as e:
    print(f"An error occurred during selection: {e}")
    exit()
# Out:
# Loaded 89997 dependency graphs and 89997 context graphs.
# Selected 200 valid dependency graphs and 200 valid context graphs.

# %% [markdown]
# This cell defines a function to validate graphs for training, checking node features, edge indices, edge attributes, and noun/adjective indices. It loads dependency and contextual graphs, validates all pairs, and saves the valid ones to pickle files.

# %%
import pickle
import torch
from torch_geometric.data import Data

def is_valid_graph(graph, graph_idx, graph_type):
    """Validate a graph for training, ensuring flat integer noun_indices and adj_indices."""
    try:

        if graph.x is None or not torch.isfinite(graph.x).all() or torch.isnan(graph.x).any():
            print(f"{graph_type} graph {graph_idx}: Invalid x (NaN/Inf or None)")
            return False
        
        if graph.edge_index is not None and graph.edge_index.numel() > 0:
            if not torch.isfinite(graph.edge_index).all() or torch.isnan(graph.edge_index).any():
                print(f"{graph_type} graph {graph_idx}: Invalid edge_index (NaN/Inf)")
                return False
            num_nodes = graph.x.shape[0]
            max_idx = graph.edge_index.max().item()
            if max_idx >= num_nodes:
                print(f"{graph_type} graph {graph_idx}: Invalid edge_index (max index {max_idx}, num_nodes {num_nodes})")
                return False
        

        if graph_type == "Dependency" and hasattr(graph, 'edge_attr') and graph.edge_attr is not None:
            if not torch.isfinite(graph.edge_attr).all() or torch.isnan(graph.edge_attr).any():
                print(f"{graph_type} graph {graph_idx}: Invalid edge_attr (NaN/Inf)")
                return False
            if graph.edge_attr.numel() > 0:
                valid_mask = (graph.edge_attr >= 0) & (graph.edge_attr < 50) | (graph.edge_attr == -1)
                if not valid_mask.all():
                    print(f"{graph_type} graph {graph_idx}: Invalid edge_attr values: {graph.edge_attr[~valid_mask].unique()}")
                    return False
            if graph.edge_attr.numel() == 0:
                print(f"{graph_type} graph {graph_idx}: Empty edge_attr")
        
       
        if graph_type == "Dependency":
            if not (hasattr(graph, 'noun_indices') and hasattr(graph, 'adj_indices')):
                print(f"{graph_type} graph {graph_idx}: Missing noun_indices or adj_indices")
                return False
            num_nodes = graph.x.shape[0]
        
            try:
                noun_indices = [idx for idx in graph.noun_indices if isinstance(idx, int) and idx < num_nodes and idx >= 0]
                adj_indices = [idx for idx in graph.adj_indices if isinstance(idx, int) and idx < num_nodes and idx >= 0]
            except TypeError:
                print(f"{graph_type} graph {graph_idx}: Invalid noun_indices or adj_indices structure (not flat integers)")
                return False
            if not noun_indices:
                print(f"{graph_type} graph {graph_idx}: Empty or invalid noun_indices")
            if not adj_indices:
                print(f"{graph_type} graph {graph_idx}: Empty or invalid adj_indices")
            return bool(noun_indices and adj_indices)
        
        return True
    except Exception as e:
        print(f"{graph_type} graph {graph_idx}: Error during validation: {e}")
        return False

try:
   
    with open('data/yelp_restaurant_dep_graphs_valid.pkl', 'rb') as f:
        dep_graphs = pickle.load(f)
    with open('data/yelp_restaurant_context_graphs_valid.pkl', 'rb') as f:
        context_graphs = pickle.load(f)
    
    print(f"Loaded {len(dep_graphs)} dependency graphs and {len(context_graphs)} context graphs.")
    

    if len(dep_graphs) != len(context_graphs):
        raise ValueError("Mismatch between number of dependency and context graphs.")
    

    valid_dep_graphs = []
    valid_context_graphs = []
    for idx in range(len(dep_graphs)):
        if is_valid_graph(dep_graphs[idx], idx, "Dependency") and is_valid_graph(context_graphs[idx], idx, "Context"):
            valid_dep_graphs.append(dep_graphs[idx])
            valid_context_graphs.append(context_graphs[idx])
            print(f"Graph pair {idx}: Valid with non-empty integer noun_indices and adj_indices")
        else:
            print(f"Skipping graph pair {idx} due to invalid data.")
    
    num_valid = len(valid_dep_graphs)
    print(f"Selected {num_valid} valid dependency graphs and {len(valid_context_graphs)} valid context graphs.")
    
    if num_valid == 0:
        raise ValueError("No valid graph pairs found.")
    
   
    with open('data/yelp_restaurant_dep_graph_valid.pkl', 'wb') as f:
        pickle.dump(valid_dep_graphs, f)
    with open('data/yelp_restaurant_context_graph_valid.pkl', 'wb') as f:
        pickle.dump(valid_context_graphs, f)
    print("Saved all valid graph pairs to 'data/yelp_restaurant_dep_graph_valid.pkl' and 'data/yelp_restaurant_context_graph_valid.pkl'.")

except FileNotFoundError as e:
    print(f"Graph files not found: {e}. Ensure 'data/yelp_restaurant_dep_graphs_valid.pkl' and 'data/yelp_restaurant_context_graphs_valid.pkl' exist.")
    exit()
except Exception as e:
    print(f"An error occurred during selection: {e}")
    exit()
# Out:
# Loaded 89997 dependency graphs and 89997 context graphs.
# Graph pair 0: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 1: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 2: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 3: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 4: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 5: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 6: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 7: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 8: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 9: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 10: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 11: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 12: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 13: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 14: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 15: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 16: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 17: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 18: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 19: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 20: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 21: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 22: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 23: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 24: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 25: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 26: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 27: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 28: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 29: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 30: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 31: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 32: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 33: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 34: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 35: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 36: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 37: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 38: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 39: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 40: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 41: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 42: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 43: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 44: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 45: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 46: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 47: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 48: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 49: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 50: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 51: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 52: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 53: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 54: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 55: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 56: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 57: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 58: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 59: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 60: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 61: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 62: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 63: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 64: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 65: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 66: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 67: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 68: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 69: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 70: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 71: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 72: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 73: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 74: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 75: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 76: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 77: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 78: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 79: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 80: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 81: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 82: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 83: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 84: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 85: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 86: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 87: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 88: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 89: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 90: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 91: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 92: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 93: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 94: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 95: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 96: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 97: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 98: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 99: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 100: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 101: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 102: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 103: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 104: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 105: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 106: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 107: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 108: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 109: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 110: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 111: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 112: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 113: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 114: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 115: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 116: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 117: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 118: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 119: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 120: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 121: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 122: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 123: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 124: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 125: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 126: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 127: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 128: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 129: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 130: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 131: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 132: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 133: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 134: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 135: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 136: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 137: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 138: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 139: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 140: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 141: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 142: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 143: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 144: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 145: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 146: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 147: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 148: Valid with non-empty integer noun_indices and adj_indices
# Dependency graph 149: Empty or invalid noun_indices
# Dependency graph 149: Empty or invalid adj_indices
# Skipping graph pair 149 due to invalid data.
# Graph pair 150: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 151: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 152: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 153: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 154: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 155: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 156: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 157: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 158: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 159: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 160: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 161: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 162: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 163: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 164: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 165: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 166: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 167: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 168: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 169: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 170: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 171: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 172: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 173: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 174: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 175: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 176: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 177: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 178: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 179: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 180: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 181: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 182: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 183: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 184: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 185: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 186: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 187: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 188: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 189: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 190: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 191: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 192: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 193: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 194: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 195: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 196: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 197: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 198: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 199: Valid with non-empty integer noun_indices and adj_indices
# Graph pair 200: Valid with non-empty integer noun_indices and adj_indices
# Selected 200 valid dependency graphs and 200 valid context graphs.
# Saved 200 clean graph pairs to 'data/yelp_restaurant_dep_graphs_200_clean.pkl' and 'data/yelp_restaurant_context_graphs_200_clean.pkl'.

# %% [markdown]
# This cell sets up the environment, loads dependency types and all valid graph pairs from pickle files, and trains a `HybridGCN` model combining T-GCN (contextual) and ARGCN (dependency) for pre-training. It performs two tasks: predicting opinion word embeddings and dependency types, logs losses, and saves the trained model checkpoint.

# %%
import pickle
import torch
import numpy as np
import random
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader
import pytorch_lightning as pl
from torch_geometric.nn import GCNConv

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


try:
    with open('data/dep_types.pkl', 'rb') as f:
        dep_data = pickle.load(f)
    dep_types = dep_data['dep_types']
    dep_type_to_idx = dep_data['dep_type_to_idx']
    print(f"Loaded dep_types and dep_type_to_idx (num_dep_types: {len(dep_types)})")
except FileNotFoundError:
    print("Dependency types file not found. Ensure 'data/dep_types.pkl' exists.")
    exit()
except Exception as e:
    print(f"Error loading dependency types: {e}")
    exit()

try:

    with open('data/yelp_restaurant_dep_graph_valid.pkl', 'rb') as f:
        dep_graphs = pickle.load(f)
    with open('data/yelp_restaurant_context_graph_valid.pkl', 'rb') as f:
        context_graphs = pickle.load(f)
    
    print(f"Loaded {len(dep_graphs)} valid dependency graphs and {len(context_graphs)} valid context graphs.")
    
   
    if len(dep_graphs) != len(context_graphs):
        raise ValueError("Mismatch between number of valid dependency and context graphs.")

except FileNotFoundError as e:
    print(f"Graph files not found: {e}. Ensure 'data/yelp_restaurant_dep_graph_valid.pkl' and 'data/yelp_restaurant_context_graph_valid.pkl' exist.")
    exit()
except Exception as e:
    print(f"An error occurred while loading valid graphs: {e}")
    exit()

class HybridGCN(pl.LightningModule):
    def __init__(self, input_dim=768, hidden_dim=256, num_dep_types=50):
        super().__init__()
        self.save_hyperparameters()
        self.tgcn_conv1 = GCNConv(input_dim, hidden_dim)
        self.tgcn_conv2 = GCNConv(hidden_dim, hidden_dim)
        self.argcn_conv1 = GCNConv(input_dim, hidden_dim)
        self.argcn_conv2 = GCNConv(hidden_dim, hidden_dim)
        self.type_emb = torch.nn.Embedding(num_dep_types, hidden_dim)
        self.fc_node = torch.nn.Linear(hidden_dim * 3, input_dim)
        self.fc_edge = torch.nn.Linear(hidden_dim, num_dep_types)
        self.dep_type_to_idx = dep_type_to_idx

    def forward(self, context_data, dep_data, target_idx=None, opinion_idx=None, task='node'):
        x_tgcn = context_data.x.to(device)
        edge_index_tgcn = context_data.edge_index.to(device)
        x_argcn = dep_data.x.to(device)
        edge_index_argcn = dep_data.edge_index.to(device)
        edge_attr = dep_data.edge_attr.to(device) if dep_data.edge_attr is not None else None
        num_nodes_tgcn = x_tgcn.shape[0]
        num_nodes_argcn = x_argcn.shape[0]
        if edge_index_tgcn.numel() > 0 and edge_index_tgcn.max().item() >= num_nodes_tgcn:
            raise ValueError(f"Invalid edge_index_tgcn: max index {edge_index_tgcn.max().item()}, num_nodes {num_nodes_tgcn}")
        if edge_index_argcn.numel() > 0 and edge_index_argcn.max().item() >= num_nodes_argcn:
            raise ValueError(f"Invalid edge_index_argcn: max index {edge_index_argcn.max().item()}, num_nodes {num_nodes_argcn}")
        if edge_attr is not None and edge_attr.numel() > 0:
            valid_mask = (edge_attr >= 0) & (edge_attr < len(dep_types)) | (edge_attr == -1)
            if not valid_mask.all():
                raise ValueError(f"Invalid edge_attr values: {edge_attr[~valid_mask].unique()}. Must be in [0, {len(dep_types)-1}] or -1.")

        x_tgcn1 = torch.relu(self.tgcn_conv1(x_tgcn, edge_index_tgcn))
        x_tgcn2 = torch.relu(self.tgcn_conv2(x_tgcn1, edge_index_tgcn))
        x_tgcn = (x_tgcn1 + x_tgcn2) / 2

        edge_weights = torch.ones(edge_index_argcn.size(1), device=device)
        if edge_attr is not None:
            valid_mask = edge_attr != -1
            valid_edge_attr = edge_attr[valid_mask]
            if valid_edge_attr.numel() > 0:
                edge_weights[valid_mask] = self.type_emb(valid_edge_attr).mean(dim=1)
        x_argcn1 = torch.relu(self.argcn_conv1(x_argcn, edge_index_argcn, edge_weights))
        x_argcn2 = torch.relu(self.argcn_conv2(x_argcn1, edge_index_argcn, edge_weights))
        x_argcn = (x_argcn1 + x_argcn2) / 2

        if task == 'node' and target_idx is not None and opinion_idx is not None:
            if target_idx >= num_nodes_tgcn or opinion_idx >= num_nodes_tgcn or opinion_idx >= num_nodes_argcn:
                raise ValueError(f"Invalid node indices: target_idx={target_idx}, opinion_idx={opinion_idx}, num_nodes_tgcn={num_nodes_tgcn}, num_nodes_argcn={num_nodes_argcn}")
            x_tgcn_target = x_tgcn[target_idx].unsqueeze(0)
            x_tgcn_opinion = x_tgcn[opinion_idx].unsqueeze(0)
            x_argcn_opinion = x_argcn[opinion_idx].unsqueeze(0)
            x_combined = torch.cat([x_tgcn_target, x_tgcn_opinion, x_argcn_opinion], dim=-1)
            return self.fc_node(x_combined)
        elif task == 'edge' and opinion_idx is not None:
            if opinion_idx >= num_nodes_argcn:
                raise ValueError(f"Invalid opinion_idx for edge task: {opinion_idx}, num_nodes {num_nodes_argcn}")
            return self.fc_edge(x_argcn[opinion_idx].unsqueeze(0))
        else:
            raise ValueError("Invalid task or indices.")

    def training_step(self, batch, batch_idx):
        context_data, dep_data = batch
        context_data = context_data.to(device)
        dep_data = dep_data.to(device)
        loss = torch.tensor(0.0, device=device, requires_grad=True)

        try:
    
            if context_data.x.shape[0] == 0 or dep_data.x.shape[0] == 0:
                print(f"Skipping graph {batch_idx}: Empty graph (context nodes: {context_data.x.shape[0]}, dep nodes: {dep_data.x.shape[0]})")
                return None
            
            if context_data.edge_index.numel() > 0:
                max_idx_context = context_data.edge_index.max().item()
                if max_idx_context >= context_data.x.shape[0]:
                    raise ValueError(f"Invalid edge_index_context in graph {batch_idx}: max index {max_idx_context}, num_nodes {context_data.x.shape[0]}")
            if dep_data.edge_index.numel() > 0:
                max_idx_dep = dep_data.edge_index.max().item()
                if max_idx_dep >= dep_data.x.shape[0]:
                    raise ValueError(f"Invalid edge_index_dep in graph {batch_idx}: max index {max_idx_dep}, num_nodes {dep_data.x.shape[0]}")

            def flatten_indices(indices):
                flat_indices = []
                for item in indices:
                    if isinstance(item, (list, tuple)):
                        flat_indices.extend([idx for idx in item if isinstance(idx, int)])
                    elif isinstance(item, int):
                        flat_indices.append(item)
                return flat_indices

            num_nodes = dep_data.x.shape[0]
            noun_indices = [idx for idx in flatten_indices(dep_data.noun_indices) if idx < num_nodes and idx >= 0]
            adj_indices = [idx for idx in flatten_indices(dep_data.adj_indices) if idx < num_nodes and idx >= 0]
            edge_attr_len = dep_data.edge_attr.numel() if dep_data.edge_attr is not None else 0

            node_loss = torch.tensor(0.0, device=device, requires_grad=True)
            if noun_indices and adj_indices:
                target_idx = random.choice(noun_indices)
                opinion_idx = random.choice(adj_indices)
                true_embedding = dep_data.x[opinion_idx].clone()
                dep_data.x[opinion_idx] = torch.zeros_like(true_embedding)
                context_data.x[opinion_idx] = torch.zeros_like(true_embedding)
                pred = self(context_data, dep_data, target_idx=target_idx, opinion_idx=opinion_idx, task='node')
                node_loss = torch.nn.MSELoss()(pred.squeeze(0), true_embedding)
                loss = loss + node_loss
                self.log('node_loss', node_loss, on_step=True, on_epoch=True, prog_bar=True, batch_size=1, sync_dist=False, reduce_fx="mean")
            else:
                print(f"Graph {batch_idx}: Skipping node loss (empty noun_indices or adj_indices)")

            edge_loss = torch.tensor(0.0, device=device, requires_grad=True)
            if dep_data.edge_attr is not None and dep_data.edge_attr.numel() > 0 and adj_indices:
                edge_idx = random.randint(0, len(dep_data.edge_attr) - 1)
                true_type_idx = dep_data.edge_attr[edge_idx].item()
                new_edge_attr = dep_data.edge_attr.clone()
                new_edge_attr[edge_idx] = -1
                dep_data.edge_attr = new_edge_attr
                opinion_idx = random.choice(adj_indices)
                if true_type_idx in self.dep_type_to_idx.values():
                    edge_pred = self(context_data, dep_data, target_idx=None, opinion_idx=opinion_idx, task='edge')
                    edge_loss = torch.nn.CrossEntropyLoss()(edge_pred, torch.tensor([true_type_idx], device=device))
                    loss = loss + edge_loss
                    self.log('edge_loss', edge_loss, on_step=True, on_epoch=True, prog_bar=True, batch_size=1, sync_dist=False, reduce_fx="mean")
                else:
                    print(f"Graph {batch_idx}: Skipping edge loss (invalid true_type_idx: {true_type_idx})")
            else:
                print(f"Graph {batch_idx}: Skipping edge loss (empty edge_attr or adj_indices)")

            self.log('train_loss', loss, on_step=True, on_epoch=True, prog_bar=True, batch_size=1, sync_dist=False, reduce_fx="mean")
            return loss

        except Exception as e:
            print(f"Skipping graph {batch_idx} due to error: {e}")
            return None

    def train_dataloader(self):

        dataset = list(zip(context_graphs, dep_graphs))
        return DataLoader(dataset, batch_size=1, shuffle=True, num_workers=0, pin_memory=True)

    def on_train_epoch_end(self):
        train_loss = self.trainer.logged_metrics.get('train_loss_epoch', 'N/A')
        node_loss = self.trainer.logged_metrics.get('node_loss_epoch', 'N/A')
        edge_loss = self.trainer.logged_metrics.get('edge_loss_epoch', 'N/A')
        print(f"Epoch {self.current_epoch} - Train Loss: {train_loss}, Node Loss: {node_loss}, Edge Loss: {edge_loss}")

    def configure_optimizers(self):
        return torch.optim.Adam(self.parameters(), lr=0.001)

try:
    model = HybridGCN(num_dep_types=len(dep_types))
    model.dep_type_to_idx = dep_type_to_idx
    trainer = pl.Trainer(
        max_epochs=10,
        accelerator='gpu' if torch.cuda.is_available() else 'cpu',
        devices=1,
        log_every_n_steps=5,
        enable_checkpointing=True,
        default_root_dir='checkpoints/'
    )
    trainer.fit(model)
    trainer.save_checkpoint('data/pretrained_gcn_1.ckpt')
    print("Pre-training completed. Checkpoint saved at: data/pretrained_final.ckpt")
except Exception as e:
    print(f"Training failed: {e}")
    raise e
# Out:
# Loaded dep_types and dep_type_to_idx (num_dep_types: 44)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# You are using a CUDA device ('NVIDIA L40S') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# Loaded 200 valid dependency graphs and 200 valid context graphs.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name        | Type      | Params
# ------------------------------------------
# 0 | tgcn_conv1  | GCNConv   | 196 K
# 1 | tgcn_conv2  | GCNConv   | 65.8 K
# 2 | argcn_conv1 | GCNConv   | 196 K
# 3 | argcn_conv2 | GCNConv   | 65.8 K
# 4 | type_emb    | Embedding | 11.3 K
# 5 | fc_node     | Linear    | 590 K
# 6 | fc_edge     | Linear    | 11.3 K
# ------------------------------------------
# 1.1 M     Trainable params
# 0         Non-trainable params
# 1.1 M     Total params
# 4.554     Total estimated model params size (MB)
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:430: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 16 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# Graph 0: context nodes=76, edge_index_context.max()=75, dep nodes=76, edge_index_dep.max()=75, noun_indices=9, adj_indices=5, edge_attr_len=74
# Graph 1: context nodes=36, edge_index_context.max()=35, dep nodes=36, edge_index_dep.max()=35, noun_indices=7, adj_indices=5, edge_attr_len=35
# Graph 2: context nodes=99, edge_index_context.max()=98, dep nodes=99, edge_index_dep.max()=98, noun_indices=19, adj_indices=10, edge_attr_len=98
# Graph 3: context nodes=66, edge_index_context.max()=65, dep nodes=66, edge_index_dep.max()=65, noun_indices=10, adj_indices=10, edge_attr_len=64
# Graph 4: context nodes=175, edge_index_context.max()=174, dep nodes=175, edge_index_dep.max()=174, noun_indices=26, adj_indices=18, edge_attr_len=173
# Graph 5: context nodes=36, edge_index_context.max()=35, dep nodes=36, edge_index_dep.max()=35, noun_indices=9, adj_indices=3, edge_attr_len=35
# Graph 6: context nodes=97, edge_index_context.max()=96, dep nodes=97, edge_index_dep.max()=96, noun_indices=17, adj_indices=5, edge_attr_len=96
# Graph 7: context nodes=138, edge_index_context.max()=137, dep nodes=138, edge_index_dep.max()=137, noun_indices=29, adj_indices=13, edge_attr_len=134
# Graph 8: context nodes=204, edge_index_context.max()=203, dep nodes=204, edge_index_dep.max()=203, noun_indices=35, adj_indices=13, edge_attr_len=203
# Graph 9: context nodes=216, edge_index_context.max()=215, dep nodes=216, edge_index_dep.max()=215, noun_indices=38, adj_indices=18, edge_attr_len=214
# Graph 10: context nodes=59, edge_index_context.max()=58, dep nodes=59, edge_index_dep.max()=58, noun_indices=11, adj_indices=7, edge_attr_len=58
# Graph 11: context nodes=51, edge_index_context.max()=50, dep nodes=51, edge_index_dep.max()=50, noun_indices=8, adj_indices=5, edge_attr_len=50
# Graph 12: context nodes=32, edge_index_context.max()=31, dep nodes=32, edge_index_dep.max()=31, noun_indices=6, adj_indices=4, edge_attr_len=31
# Graph 13: context nodes=106, edge_index_context.max()=105, dep nodes=106, edge_index_dep.max()=105, noun_indices=24, adj_indices=8, edge_attr_len=105
# Graph 14: context nodes=61, edge_index_context.max()=60, dep nodes=61, edge_index_dep.max()=60, noun_indices=15, adj_indices=7, edge_attr_len=60
# Graph 15: context nodes=25, edge_index_context.max()=24, dep nodes=25, edge_index_dep.max()=24, noun_indices=8, adj_indices=5, edge_attr_len=24
# Graph 16: context nodes=73, edge_index_context.max()=72, dep nodes=73, edge_index_dep.max()=72, noun_indices=11, adj_indices=7, edge_attr_len=72
# Graph 17: context nodes=23, edge_index_context.max()=22, dep nodes=23, edge_index_dep.max()=22, noun_indices=7, adj_indices=5, edge_attr_len=22
# Graph 18: context nodes=84, edge_index_context.max()=83, dep nodes=84, edge_index_dep.max()=83, noun_indices=17, adj_indices=7, edge_attr_len=81
# Graph 19: context nodes=119, edge_index_context.max()=118, dep nodes=119, edge_index_dep.max()=118, noun_indices=21, adj_indices=6, edge_attr_len=118
# Graph 20: context nodes=135, edge_index_context.max()=134, dep nodes=135, edge_index_dep.max()=134, noun_indices=23, adj_indices=15, edge_attr_len=133
# Graph 21: context nodes=120, edge_index_context.max()=119, dep nodes=120, edge_index_dep.max()=119, noun_indices=21, adj_indices=12, edge_attr_len=115
# Graph 22: context nodes=19, edge_index_context.max()=18, dep nodes=19, edge_index_dep.max()=18, noun_indices=3, adj_indices=1, edge_attr_len=18
# Graph 23: context nodes=79, edge_index_context.max()=78, dep nodes=79, edge_index_dep.max()=78, noun_indices=15, adj_indices=12, edge_attr_len=78
# Graph 24: context nodes=81, edge_index_context.max()=80, dep nodes=81, edge_index_dep.max()=80, noun_indices=12, adj_indices=11, edge_attr_len=80
# Graph 25: context nodes=45, edge_index_context.max()=44, dep nodes=45, edge_index_dep.max()=44, noun_indices=8, adj_indices=1, edge_attr_len=44
# Graph 26: context nodes=77, edge_index_context.max()=76, dep nodes=77, edge_index_dep.max()=76, noun_indices=19, adj_indices=9, edge_attr_len=76
# Graph 27: context nodes=235, edge_index_context.max()=234, dep nodes=235, edge_index_dep.max()=234, noun_indices=36, adj_indices=17, edge_attr_len=231
# Graph 28: context nodes=18, edge_index_context.max()=17, dep nodes=18, edge_index_dep.max()=17, noun_indices=6, adj_indices=3, edge_attr_len=17
# Graph 29: context nodes=171, edge_index_context.max()=170, dep nodes=171, edge_index_dep.max()=170, noun_indices=29, adj_indices=11, edge_attr_len=170
# Graph 30: context nodes=90, edge_index_context.max()=89, dep nodes=90, edge_index_dep.max()=89, noun_indices=13, adj_indices=6, edge_attr_len=87
# Graph 31: context nodes=47, edge_index_context.max()=46, dep nodes=47, edge_index_dep.max()=46, noun_indices=10, adj_indices=10, edge_attr_len=46
# Graph 32: context nodes=67, edge_index_context.max()=66, dep nodes=67, edge_index_dep.max()=66, noun_indices=16, adj_indices=4, edge_attr_len=65
# Graph 33: context nodes=33, edge_index_context.max()=32, dep nodes=33, edge_index_dep.max()=32, noun_indices=4, adj_indices=7, edge_attr_len=32
# Graph 34: context nodes=27, edge_index_context.max()=26, dep nodes=27, edge_index_dep.max()=26, noun_indices=4, adj_indices=3, edge_attr_len=26
# Graph 35: context nodes=41, edge_index_context.max()=40, dep nodes=41, edge_index_dep.max()=40, noun_indices=10, adj_indices=3, edge_attr_len=40
# Graph 36: context nodes=23, edge_index_context.max()=22, dep nodes=23, edge_index_dep.max()=22, noun_indices=3, adj_indices=6, edge_attr_len=22
# Graph 37: context nodes=121, edge_index_context.max()=120, dep nodes=121, edge_index_dep.max()=120, noun_indices=20, adj_indices=13, edge_attr_len=119
# Graph 38: context nodes=262, edge_index_context.max()=261, dep nodes=262, edge_index_dep.max()=261, noun_indices=40, adj_indices=22, edge_attr_len=258
# Graph 39: context nodes=109, edge_index_context.max()=108, dep nodes=109, edge_index_dep.max()=108, noun_indices=20, adj_indices=9, edge_attr_len=108
# Graph 40: context nodes=102, edge_index_context.max()=101, dep nodes=102, edge_index_dep.max()=101, noun_indices=21, adj_indices=10, edge_attr_len=97
# Graph 41: context nodes=53, edge_index_context.max()=52, dep nodes=53, edge_index_dep.max()=52, noun_indices=9, adj_indices=4, edge_attr_len=52
# Graph 42: context nodes=21, edge_index_context.max()=20, dep nodes=21, edge_index_dep.max()=20, noun_indices=6, adj_indices=5, edge_attr_len=20
# Graph 43: context nodes=84, edge_index_context.max()=83, dep nodes=84, edge_index_dep.max()=83, noun_indices=21, adj_indices=7, edge_attr_len=82
# Graph 44: context nodes=113, edge_index_context.max()=112, dep nodes=113, edge_index_dep.max()=112, noun_indices=22, adj_indices=7, edge_attr_len=112
# Graph 45: context nodes=15, edge_index_context.max()=14, dep nodes=15, edge_index_dep.max()=14, noun_indices=2, adj_indices=2, edge_attr_len=14
# Graph 46: context nodes=39, edge_index_context.max()=38, dep nodes=39, edge_index_dep.max()=38, noun_indices=6, adj_indices=7, edge_attr_len=37
# Graph 47: context nodes=68, edge_index_context.max()=67, dep nodes=68, edge_index_dep.max()=67, noun_indices=15, adj_indices=11, edge_attr_len=67
# Graph 48: context nodes=107, edge_index_context.max()=106, dep nodes=107, edge_index_dep.max()=106, noun_indices=16, adj_indices=10, edge_attr_len=106
# Graph 49: context nodes=55, edge_index_context.max()=54, dep nodes=55, edge_index_dep.max()=54, noun_indices=15, adj_indices=7, edge_attr_len=54
# Graph 50: context nodes=55, edge_index_context.max()=54, dep nodes=55, edge_index_dep.max()=54, noun_indices=13, adj_indices=3, edge_attr_len=54
# Graph 51: context nodes=163, edge_index_context.max()=162, dep nodes=163, edge_index_dep.max()=162, noun_indices=30, adj_indices=15, edge_attr_len=161
# Graph 52: context nodes=213, edge_index_context.max()=212, dep nodes=213, edge_index_dep.max()=212, noun_indices=45, adj_indices=14, edge_attr_len=212
# Graph 53: context nodes=54, edge_index_context.max()=53, dep nodes=54, edge_index_dep.max()=53, noun_indices=8, adj_indices=7, edge_attr_len=53
# Graph 54: context nodes=29, edge_index_context.max()=28, dep nodes=29, edge_index_dep.max()=28, noun_indices=11, adj_indices=3, edge_attr_len=28
# Graph 55: context nodes=135, edge_index_context.max()=134, dep nodes=135, edge_index_dep.max()=134, noun_indices=36, adj_indices=11, edge_attr_len=133
# Graph 56: context nodes=78, edge_index_context.max()=77, dep nodes=78, edge_index_dep.max()=77, noun_indices=15, adj_indices=9, edge_attr_len=76
# Graph 57: context nodes=153, edge_index_context.max()=152, dep nodes=153, edge_index_dep.max()=152, noun_indices=29, adj_indices=12, edge_attr_len=151
# Graph 58: context nodes=59, edge_index_context.max()=58, dep nodes=59, edge_index_dep.max()=58, noun_indices=14, adj_indices=7, edge_attr_len=58
# Graph 59: context nodes=60, edge_index_context.max()=59, dep nodes=60, edge_index_dep.max()=59, noun_indices=12, adj_indices=3, edge_attr_len=59
# Graph 60: context nodes=146, edge_index_context.max()=145, dep nodes=146, edge_index_dep.max()=145, noun_indices=20, adj_indices=12, edge_attr_len=145
# Graph 61: context nodes=63, edge_index_context.max()=62, dep nodes=63, edge_index_dep.max()=62, noun_indices=13, adj_indices=5, edge_attr_len=60
# Graph 62: context nodes=51, edge_index_context.max()=50, dep nodes=51, edge_index_dep.max()=50, noun_indices=10, adj_indices=6, edge_attr_len=50
# Graph 63: context nodes=33, edge_index_context.max()=32, dep nodes=33, edge_index_dep.max()=32, noun_indices=7, adj_indices=3, edge_attr_len=32
# Graph 64: context nodes=32, edge_index_context.max()=31, dep nodes=32, edge_index_dep.max()=31, noun_indices=8, adj_indices=5, edge_attr_len=31
# Graph 65: context nodes=33, edge_index_context.max()=32, dep nodes=33, edge_index_dep.max()=32, noun_indices=8, adj_indices=6, edge_attr_len=32
# Graph 66: context nodes=200, edge_index_context.max()=199, dep nodes=200, edge_index_dep.max()=199, noun_indices=38, adj_indices=11, edge_attr_len=199
# Graph 67: context nodes=168, edge_index_context.max()=167, dep nodes=168, edge_index_dep.max()=167, noun_indices=29, adj_indices=20, edge_attr_len=167
# Graph 68: context nodes=114, edge_index_context.max()=113, dep nodes=114, edge_index_dep.max()=113, noun_indices=24, adj_indices=16, edge_attr_len=112
# Graph 69: context nodes=183, edge_index_context.max()=182, dep nodes=183, edge_index_dep.max()=182, noun_indices=30, adj_indices=18, edge_attr_len=181
# Graph 70: context nodes=510, edge_index_context.max()=509, dep nodes=510, edge_index_dep.max()=509, noun_indices=69, adj_indices=23, edge_attr_len=503
# Graph 71: context nodes=39, edge_index_context.max()=38, dep nodes=39, edge_index_dep.max()=38, noun_indices=7, adj_indices=6, edge_attr_len=37
# Graph 72: context nodes=114, edge_index_context.max()=113, dep nodes=114, edge_index_dep.max()=113, noun_indices=25, adj_indices=12, edge_attr_len=113
# Graph 73: context nodes=145, edge_index_context.max()=144, dep nodes=145, edge_index_dep.max()=144, noun_indices=32, adj_indices=20, edge_attr_len=144
# Graph 74: context nodes=65, edge_index_context.max()=64, dep nodes=65, edge_index_dep.max()=64, noun_indices=12, adj_indices=4, edge_attr_len=64
# Graph 75: context nodes=233, edge_index_context.max()=232, dep nodes=233, edge_index_dep.max()=232, noun_indices=40, adj_indices=28, edge_attr_len=232
# Graph 76: context nodes=57, edge_index_context.max()=56, dep nodes=57, edge_index_dep.max()=56, noun_indices=21, adj_indices=9, edge_attr_len=56
# Graph 77: context nodes=180, edge_index_context.max()=179, dep nodes=180, edge_index_dep.max()=179, noun_indices=40, adj_indices=18, edge_attr_len=178
# Graph 78: context nodes=40, edge_index_context.max()=39, dep nodes=40, edge_index_dep.max()=39, noun_indices=10, adj_indices=6, edge_attr_len=39
# Graph 79: context nodes=198, edge_index_context.max()=197, dep nodes=198, edge_index_dep.max()=197, noun_indices=44, adj_indices=20, edge_attr_len=193
# Graph 80: context nodes=70, edge_index_context.max()=69, dep nodes=70, edge_index_dep.max()=69, noun_indices=15, adj_indices=6, edge_attr_len=68
# Graph 81: context nodes=177, edge_index_context.max()=176, dep nodes=177, edge_index_dep.max()=176, noun_indices=28, adj_indices=8, edge_attr_len=173
# Graph 82: context nodes=21, edge_index_context.max()=20, dep nodes=21, edge_index_dep.max()=20, noun_indices=4, adj_indices=3, edge_attr_len=20
# Graph 83: context nodes=144, edge_index_context.max()=143, dep nodes=144, edge_index_dep.max()=143, noun_indices=28, adj_indices=16, edge_attr_len=142
# Graph 84: context nodes=42, edge_index_context.max()=41, dep nodes=42, edge_index_dep.max()=41, noun_indices=10, adj_indices=4, edge_attr_len=41
# Graph 85: context nodes=94, edge_index_context.max()=93, dep nodes=94, edge_index_dep.max()=93, noun_indices=6, adj_indices=9, edge_attr_len=90
# Graph 86: context nodes=61, edge_index_context.max()=60, dep nodes=61, edge_index_dep.max()=60, noun_indices=10, adj_indices=7, edge_attr_len=60
# Graph 87: context nodes=67, edge_index_context.max()=66, dep nodes=67, edge_index_dep.max()=66, noun_indices=12, adj_indices=5, edge_attr_len=64
# Graph 88: context nodes=261, edge_index_context.max()=260, dep nodes=261, edge_index_dep.max()=260, noun_indices=52, adj_indices=31, edge_attr_len=259
# Graph 89: context nodes=411, edge_index_context.max()=410, dep nodes=411, edge_index_dep.max()=410, noun_indices=86, adj_indices=28, edge_attr_len=408
# Graph 90: context nodes=420, edge_index_context.max()=419, dep nodes=420, edge_index_dep.max()=419, noun_indices=77, adj_indices=31, edge_attr_len=416
# Graph 91: context nodes=168, edge_index_context.max()=167, dep nodes=168, edge_index_dep.max()=167, noun_indices=33, adj_indices=16, edge_attr_len=165
# Graph 92: context nodes=30, edge_index_context.max()=29, dep nodes=30, edge_index_dep.max()=29, noun_indices=5, adj_indices=4, edge_attr_len=29
# Graph 93: context nodes=130, edge_index_context.max()=129, dep nodes=130, edge_index_dep.max()=129, noun_indices=24, adj_indices=9, edge_attr_len=129
# Graph 94: context nodes=52, edge_index_context.max()=51, dep nodes=52, edge_index_dep.max()=51, noun_indices=12, adj_indices=6, edge_attr_len=51
# Graph 95: context nodes=89, edge_index_context.max()=88, dep nodes=89, edge_index_dep.max()=88, noun_indices=17, adj_indices=11, edge_attr_len=88
# Graph 96: context nodes=173, edge_index_context.max()=172, dep nodes=173, edge_index_dep.max()=172, noun_indices=36, adj_indices=18, edge_attr_len=172
# Graph 97: context nodes=54, edge_index_context.max()=53, dep nodes=54, edge_index_dep.max()=53, noun_indices=16, adj_indices=12, edge_attr_len=53
# Graph 98: context nodes=95, edge_index_context.max()=94, dep nodes=95, edge_index_dep.max()=94, noun_indices=21, adj_indices=6, edge_attr_len=94
# Graph 99: context nodes=262, edge_index_context.max()=261, dep nodes=262, edge_index_dep.max()=261, noun_indices=53, adj_indices=22, edge_attr_len=258
# Graph 100: context nodes=112, edge_index_context.max()=111, dep nodes=112, edge_index_dep.max()=111, noun_indices=17, adj_indices=12, edge_attr_len=111
# Graph 101: context nodes=51, edge_index_context.max()=50, dep nodes=51, edge_index_dep.max()=50, noun_indices=12, adj_indices=5, edge_attr_len=50
# Graph 102: context nodes=46, edge_index_context.max()=45, dep nodes=46, edge_index_dep.max()=45, noun_indices=12, adj_indices=7, edge_attr_len=45
# Graph 103: context nodes=341, edge_index_context.max()=340, dep nodes=341, edge_index_dep.max()=340, noun_indices=48, adj_indices=40, edge_attr_len=338
# Graph 104: context nodes=29, edge_index_context.max()=28, dep nodes=29, edge_index_dep.max()=28, noun_indices=9, adj_indices=5, edge_attr_len=28
# Graph 105: context nodes=26, edge_index_context.max()=25, dep nodes=26, edge_index_dep.max()=25, noun_indices=5, adj_indices=3, edge_attr_len=25
# Graph 106: context nodes=108, edge_index_context.max()=107, dep nodes=108, edge_index_dep.max()=107, noun_indices=19, adj_indices=10, edge_attr_len=107
# Graph 107: context nodes=94, edge_index_context.max()=93, dep nodes=94, edge_index_dep.max()=93, noun_indices=14, adj_indices=9, edge_attr_len=92
# Graph 108: context nodes=30, edge_index_context.max()=29, dep nodes=30, edge_index_dep.max()=29, noun_indices=9, adj_indices=4, edge_attr_len=29
# Graph 109: context nodes=63, edge_index_context.max()=62, dep nodes=63, edge_index_dep.max()=62, noun_indices=15, adj_indices=6, edge_attr_len=62
# Graph 110: context nodes=78, edge_index_context.max()=77, dep nodes=78, edge_index_dep.max()=77, noun_indices=12, adj_indices=8, edge_attr_len=76
# Graph 111: context nodes=39, edge_index_context.max()=38, dep nodes=39, edge_index_dep.max()=38, noun_indices=8, adj_indices=3, edge_attr_len=38
# Graph 112: context nodes=47, edge_index_context.max()=46, dep nodes=47, edge_index_dep.max()=46, noun_indices=7, adj_indices=5, edge_attr_len=46
# Graph 113: context nodes=52, edge_index_context.max()=51, dep nodes=52, edge_index_dep.max()=51, noun_indices=18, adj_indices=7, edge_attr_len=51
# Graph 114: context nodes=132, edge_index_context.max()=131, dep nodes=132, edge_index_dep.max()=131, noun_indices=31, adj_indices=9, edge_attr_len=130
# Graph 115: context nodes=72, edge_index_context.max()=71, dep nodes=72, edge_index_dep.max()=71, noun_indices=12, adj_indices=6, edge_attr_len=71
# Graph 116: context nodes=35, edge_index_context.max()=34, dep nodes=35, edge_index_dep.max()=34, noun_indices=7, adj_indices=5, edge_attr_len=33
# Graph 117: context nodes=131, edge_index_context.max()=130, dep nodes=131, edge_index_dep.max()=130, noun_indices=27, adj_indices=14, edge_attr_len=127
# Graph 118: context nodes=47, edge_index_context.max()=46, dep nodes=47, edge_index_dep.max()=46, noun_indices=11, adj_indices=4, edge_attr_len=46
# Graph 119: context nodes=155, edge_index_context.max()=154, dep nodes=155, edge_index_dep.max()=154, noun_indices=28, adj_indices=9, edge_attr_len=154
# Graph 120: context nodes=26, edge_index_context.max()=25, dep nodes=26, edge_index_dep.max()=25, noun_indices=6, adj_indices=1, edge_attr_len=25
# Graph 121: context nodes=127, edge_index_context.max()=126, dep nodes=127, edge_index_dep.max()=126, noun_indices=21, adj_indices=8, edge_attr_len=126
# Graph 122: context nodes=63, edge_index_context.max()=62, dep nodes=63, edge_index_dep.max()=62, noun_indices=10, adj_indices=9, edge_attr_len=62
# Graph 123: context nodes=117, edge_index_context.max()=116, dep nodes=117, edge_index_dep.max()=116, noun_indices=20, adj_indices=8, edge_attr_len=116
# Graph 124: context nodes=98, edge_index_context.max()=97, dep nodes=98, edge_index_dep.max()=97, noun_indices=19, adj_indices=9, edge_attr_len=93
# Graph 125: context nodes=99, edge_index_context.max()=98, dep nodes=99, edge_index_dep.max()=98, noun_indices=20, adj_indices=9, edge_attr_len=98
# Graph 126: context nodes=77, edge_index_context.max()=76, dep nodes=77, edge_index_dep.max()=76, noun_indices=17, adj_indices=6, edge_attr_len=76
# Graph 127: context nodes=44, edge_index_context.max()=43, dep nodes=44, edge_index_dep.max()=43, noun_indices=8, adj_indices=6, edge_attr_len=43
# Graph 128: context nodes=156, edge_index_context.max()=155, dep nodes=156, edge_index_dep.max()=155, noun_indices=35, adj_indices=6, edge_attr_len=155
# Graph 129: context nodes=77, edge_index_context.max()=76, dep nodes=77, edge_index_dep.max()=76, noun_indices=17, adj_indices=5, edge_attr_len=75
# Graph 130: context nodes=86, edge_index_context.max()=85, dep nodes=86, edge_index_dep.max()=85, noun_indices=14, adj_indices=13, edge_attr_len=84
# Graph 131: context nodes=46, edge_index_context.max()=45, dep nodes=46, edge_index_dep.max()=45, noun_indices=10, adj_indices=4, edge_attr_len=45
# Graph 132: context nodes=121, edge_index_context.max()=120, dep nodes=121, edge_index_dep.max()=120, noun_indices=25, adj_indices=10, edge_attr_len=119
# Graph 133: context nodes=321, edge_index_context.max()=320, dep nodes=321, edge_index_dep.max()=320, noun_indices=39, adj_indices=22, edge_attr_len=317
# Graph 134: context nodes=89, edge_index_context.max()=88, dep nodes=89, edge_index_dep.max()=88, noun_indices=24, adj_indices=5, edge_attr_len=88
# Graph 135: context nodes=63, edge_index_context.max()=62, dep nodes=63, edge_index_dep.max()=62, noun_indices=13, adj_indices=9, edge_attr_len=62
# Graph 136: context nodes=195, edge_index_context.max()=194, dep nodes=195, edge_index_dep.max()=194, noun_indices=33, adj_indices=28, edge_attr_len=194
# Graph 137: context nodes=47, edge_index_context.max()=46, dep nodes=47, edge_index_dep.max()=46, noun_indices=10, adj_indices=5, edge_attr_len=46
# Graph 138: context nodes=58, edge_index_context.max()=57, dep nodes=58, edge_index_dep.max()=57, noun_indices=15, adj_indices=7, edge_attr_len=57
# Graph 139: context nodes=70, edge_index_context.max()=69, dep nodes=70, edge_index_dep.max()=69, noun_indices=9, adj_indices=11, edge_attr_len=69
# Graph 140: context nodes=40, edge_index_context.max()=39, dep nodes=40, edge_index_dep.max()=39, noun_indices=8, adj_indices=6, edge_attr_len=39
# Graph 141: context nodes=47, edge_index_context.max()=46, dep nodes=47, edge_index_dep.max()=46, noun_indices=9, adj_indices=5, edge_attr_len=46
# Graph 142: context nodes=17, edge_index_context.max()=16, dep nodes=17, edge_index_dep.max()=16, noun_indices=3, adj_indices=4, edge_attr_len=16
# Graph 143: context nodes=98, edge_index_context.max()=97, dep nodes=98, edge_index_dep.max()=97, noun_indices=17, adj_indices=4, edge_attr_len=94
# Graph 144: context nodes=27, edge_index_context.max()=26, dep nodes=27, edge_index_dep.max()=26, noun_indices=5, adj_indices=3, edge_attr_len=26
# Graph 145: context nodes=103, edge_index_context.max()=102, dep nodes=103, edge_index_dep.max()=102, noun_indices=27, adj_indices=13, edge_attr_len=101
# Graph 146: context nodes=256, edge_index_context.max()=255, dep nodes=256, edge_index_dep.max()=255, noun_indices=52, adj_indices=20, edge_attr_len=251
# Graph 147: context nodes=71, edge_index_context.max()=70, dep nodes=71, edge_index_dep.max()=70, noun_indices=13, adj_indices=9, edge_attr_len=70
# Graph 148: context nodes=65, edge_index_context.max()=64, dep nodes=65, edge_index_dep.max()=64, noun_indices=10, adj_indices=3, edge_attr_len=63
# Graph 149: context nodes=31, edge_index_context.max()=30, dep nodes=31, edge_index_dep.max()=30, noun_indices=8, adj_indices=6, edge_attr_len=29
# Graph 150: context nodes=313, edge_index_context.max()=312, dep nodes=313, edge_index_dep.max()=312, noun_indices=65, adj_indices=29, edge_attr_len=309
# Graph 151: context nodes=27, edge_index_context.max()=26, dep nodes=27, edge_index_dep.max()=26, noun_indices=7, adj_indices=6, edge_attr_len=26
# Graph 152: context nodes=65, edge_index_context.max()=64, dep nodes=65, edge_index_dep.max()=64, noun_indices=9, adj_indices=7, edge_attr_len=64
# Graph 153: context nodes=163, edge_index_context.max()=162, dep nodes=163, edge_index_dep.max()=162, noun_indices=33, adj_indices=10, edge_attr_len=161
# Graph 154: context nodes=161, edge_index_context.max()=160, dep nodes=161, edge_index_dep.max()=160, noun_indices=26, adj_indices=15, edge_attr_len=159
# Graph 155: context nodes=37, edge_index_context.max()=36, dep nodes=37, edge_index_dep.max()=36, noun_indices=6, adj_indices=4, edge_attr_len=36
# Graph 156: context nodes=29, edge_index_context.max()=28, dep nodes=29, edge_index_dep.max()=28, noun_indices=6, adj_indices=4, edge_attr_len=28
# Graph 157: context nodes=348, edge_index_context.max()=347, dep nodes=348, edge_index_dep.max()=347, noun_indices=53, adj_indices=19, edge_attr_len=345
# Graph 158: context nodes=47, edge_index_context.max()=46, dep nodes=47, edge_index_dep.max()=46, noun_indices=6, adj_indices=4, edge_attr_len=45
# Graph 159: context nodes=31, edge_index_context.max()=30, dep nodes=31, edge_index_dep.max()=30, noun_indices=5, adj_indices=5, edge_attr_len=30
# Graph 160: context nodes=36, edge_index_context.max()=35, dep nodes=36, edge_index_dep.max()=35, noun_indices=6, adj_indices=4, edge_attr_len=33
# Graph 161: context nodes=53, edge_index_context.max()=52, dep nodes=53, edge_index_dep.max()=52, noun_indices=17, adj_indices=9, edge_attr_len=52
# Graph 162: context nodes=38, edge_index_context.max()=37, dep nodes=38, edge_index_dep.max()=37, noun_indices=5, adj_indices=6, edge_attr_len=37
# Graph 163: context nodes=21, edge_index_context.max()=20, dep nodes=21, edge_index_dep.max()=20, noun_indices=5, adj_indices=2, edge_attr_len=20
# Graph 164: context nodes=60, edge_index_context.max()=59, dep nodes=60, edge_index_dep.max()=59, noun_indices=7, adj_indices=8, edge_attr_len=58
# Graph 165: context nodes=47, edge_index_context.max()=46, dep nodes=47, edge_index_dep.max()=46, noun_indices=12, adj_indices=4, edge_attr_len=46
# Graph 166: context nodes=118, edge_index_context.max()=117, dep nodes=118, edge_index_dep.max()=117, noun_indices=16, adj_indices=6, edge_attr_len=115
# Graph 167: context nodes=52, edge_index_context.max()=51, dep nodes=52, edge_index_dep.max()=51, noun_indices=16, adj_indices=1, edge_attr_len=51
# Graph 168: context nodes=29, edge_index_context.max()=28, dep nodes=29, edge_index_dep.max()=28, noun_indices=4, adj_indices=3, edge_attr_len=28
# Graph 169: context nodes=19, edge_index_context.max()=18, dep nodes=19, edge_index_dep.max()=18, noun_indices=4, adj_indices=3, edge_attr_len=17
# Graph 170: context nodes=19, edge_index_context.max()=18, dep nodes=19, edge_index_dep.max()=18, noun_indices=4, adj_indices=3, edge_attr_len=18
# Graph 171: context nodes=15, edge_index_context.max()=14, dep nodes=15, edge_index_dep.max()=14, noun_indices=2, adj_indices=2, edge_attr_len=14
# Graph 172: context nodes=39, edge_index_context.max()=38, dep nodes=39, edge_index_dep.max()=38, noun_indices=4, adj_indices=6, edge_attr_len=38
# Graph 173: context nodes=41, edge_index_context.max()=40, dep nodes=41, edge_index_dep.max()=40, noun_indices=10, adj_indices=5, edge_attr_len=39
# Graph 174: context nodes=82, edge_index_context.max()=81, dep nodes=82, edge_index_dep.max()=81, noun_indices=11, adj_indices=7, edge_attr_len=81
# Graph 175: context nodes=26, edge_index_context.max()=25, dep nodes=26, edge_index_dep.max()=25, noun_indices=3, adj_indices=2, edge_attr_len=25
# Graph 176: context nodes=114, edge_index_context.max()=113, dep nodes=114, edge_index_dep.max()=113, noun_indices=19, adj_indices=12, edge_attr_len=112
# Graph 177: context nodes=22, edge_index_context.max()=21, dep nodes=22, edge_index_dep.max()=21, noun_indices=6, adj_indices=2, edge_attr_len=21
# Graph 178: context nodes=65, edge_index_context.max()=64, dep nodes=65, edge_index_dep.max()=64, noun_indices=8, adj_indices=14, edge_attr_len=64
# Graph 179: context nodes=394, edge_index_context.max()=393, dep nodes=394, edge_index_dep.max()=393, noun_indices=62, adj_indices=24, edge_attr_len=390
# Graph 180: context nodes=71, edge_index_context.max()=70, dep nodes=71, edge_index_dep.max()=70, noun_indices=16, adj_indices=9, edge_attr_len=70
# Graph 181: context nodes=28, edge_index_context.max()=27, dep nodes=28, edge_index_dep.max()=27, noun_indices=5, adj_indices=2, edge_attr_len=27
# Graph 182: context nodes=101, edge_index_context.max()=100, dep nodes=101, edge_index_dep.max()=100, noun_indices=21, adj_indices=6, edge_attr_len=100
# Graph 183: context nodes=64, edge_index_context.max()=63, dep nodes=64, edge_index_dep.max()=63, noun_indices=9, adj_indices=7, edge_attr_len=61
# Graph 184: context nodes=60, edge_index_context.max()=59, dep nodes=60, edge_index_dep.max()=59, noun_indices=9, adj_indices=4, edge_attr_len=56
# Graph 185: context nodes=120, edge_index_context.max()=119, dep nodes=120, edge_index_dep.max()=119, noun_indices=25, adj_indices=8, edge_attr_len=117
# Graph 186: context nodes=163, edge_index_context.max()=162, dep nodes=163, edge_index_dep.max()=162, noun_indices=30, adj_indices=10, edge_attr_len=161
# Graph 187: context nodes=121, edge_index_context.max()=120, dep nodes=121, edge_index_dep.max()=120, noun_indices=29, adj_indices=10, edge_attr_len=120
# Graph 188: context nodes=105, edge_index_context.max()=104, dep nodes=105, edge_index_dep.max()=104, noun_indices=20, adj_indices=11, edge_attr_len=104
# Graph 189: context nodes=89, edge_index_context.max()=88, dep nodes=89, edge_index_dep.max()=88, noun_indices=15, adj_indices=4, edge_attr_len=87
# Graph 190: context nodes=47, edge_index_context.max()=46, dep nodes=47, edge_index_dep.max()=46, noun_indices=9, adj_indices=6, edge_attr_len=46
# Graph 191: context nodes=82, edge_index_context.max()=81, dep nodes=82, edge_index_dep.max()=81, noun_indices=16, adj_indices=10, edge_attr_len=81
# Graph 192: context nodes=289, edge_index_context.max()=288, dep nodes=289, edge_index_dep.max()=288, noun_indices=53, adj_indices=18, edge_attr_len=287
# Graph 193: context nodes=100, edge_index_context.max()=99, dep nodes=100, edge_index_dep.max()=99, noun_indices=24, adj_indices=5, edge_attr_len=98
# Graph 194: context nodes=60, edge_index_context.max()=59, dep nodes=60, edge_index_dep.max()=59, noun_indices=14, adj_indices=4, edge_attr_len=59
# Graph 195: context nodes=161, edge_index_context.max()=160, dep nodes=161, edge_index_dep.max()=160, noun_indices=35, adj_indices=12, edge_attr_len=159
# Graph 196: context nodes=510, edge_index_context.max()=509, dep nodes=510, edge_index_dep.max()=509, noun_indices=88, adj_indices=41, edge_attr_len=503
# Graph 197: context nodes=149, edge_index_context.max()=148, dep nodes=149, edge_index_dep.max()=148, noun_indices=28, adj_indices=9, edge_attr_len=148
# Graph 198: context nodes=46, edge_index_context.max()=45, dep nodes=46, edge_index_dep.max()=45, noun_indices=9, adj_indices=5, edge_attr_len=45
# Graph 199: context nodes=269, edge_index_context.max()=268, dep nodes=269, edge_index_dep.max()=268, noun_indices=42, adj_indices=22, edge_attr_len=266
# Epoch 0 - Train Loss: 3.401968479156494, Node Loss: 0.08613675832748413, Edge Loss: 3.3158318996429443
# Graph 0: context nodes=40, edge_index_context.max()=39, dep nodes=40, edge_index_dep.max()=39, noun_indices=8, adj_indices=6, edge_attr_len=39
# Graph 1: context nodes=78, edge_index_context.max()=77, dep nodes=78, edge_index_dep.max()=77, noun_indices=15, adj_indices=9, edge_attr_len=76
# Graph 2: context nodes=99, edge_index_context.max()=98, dep nodes=99, edge_index_dep.max()=98, noun_indices=19, adj_indices=10, edge_attr_len=98
# Graph 3: context nodes=94, edge_index_context.max()=93, dep nodes=94, edge_index_dep.max()=93, noun_indices=6, adj_indices=9, edge_attr_len=90
# Graph 4: context nodes=60, edge_index_context.max()=59, dep nodes=60, edge_index_dep.max()=59, noun_indices=12, adj_indices=3, edge_attr_len=59
# Graph 5: context nodes=76, edge_index_context.max()=75, dep nodes=76, edge_index_dep.max()=75, noun_indices=9, adj_indices=5, edge_attr_len=74
# Graph 6: context nodes=163, edge_index_context.max()=162, dep nodes=163, edge_index_dep.max()=162, noun_indices=33, adj_indices=10, edge_attr_len=161
# Graph 7: context nodes=95, edge_index_context.max()=94, dep nodes=95, edge_index_dep.max()=94, noun_indices=21, adj_indices=6, edge_attr_len=94
# Graph 8: context nodes=29, edge_index_context.max()=28, dep nodes=29, edge_index_dep.max()=28, noun_indices=11, adj_indices=3, edge_attr_len=28
# Graph 9: context nodes=183, edge_index_context.max()=182, dep nodes=183, edge_index_dep.max()=182, noun_indices=30, adj_indices=18, edge_attr_len=181
# Graph 10: context nodes=52, edge_index_context.max()=51, dep nodes=52, edge_index_dep.max()=51, noun_indices=18, adj_indices=7, edge_attr_len=51
# Graph 11: context nodes=113, edge_index_context.max()=112, dep nodes=113, edge_index_dep.max()=112, noun_indices=22, adj_indices=7, edge_attr_len=112
# Graph 12: context nodes=52, edge_index_context.max()=51, dep nodes=52, edge_index_dep.max()=51, noun_indices=12, adj_indices=6, edge_attr_len=51
# Graph 13: context nodes=15, edge_index_context.max()=14, dep nodes=15, edge_index_dep.max()=14, noun_indices=2, adj_indices=2, edge_attr_len=14
# Graph 14: context nodes=18, edge_index_context.max()=17, dep nodes=18, edge_index_dep.max()=17, noun_indices=6, adj_indices=3, edge_attr_len=17
# Graph 15: context nodes=60, edge_index_context.max()=59, dep nodes=60, edge_index_dep.max()=59, noun_indices=9, adj_indices=4, edge_attr_len=56
# Graph 16: context nodes=59, edge_index_context.max()=58, dep nodes=59, edge_index_dep.max()=58, noun_indices=11, adj_indices=7, edge_attr_len=58
# Graph 17: context nodes=118, edge_index_context.max()=117, dep nodes=118, edge_index_dep.max()=117, noun_indices=16, adj_indices=6, edge_attr_len=115
# Graph 18: context nodes=510, edge_index_context.max()=509, dep nodes=510, edge_index_dep.max()=509, noun_indices=69, adj_indices=23, edge_attr_len=503
# Graph 19: context nodes=44, edge_index_context.max()=43, dep nodes=44, edge_index_dep.max()=43, noun_indices=8, adj_indices=6, edge_attr_len=43
# Graph 20: context nodes=21, edge_index_context.max()=20, dep nodes=21, edge_index_dep.max()=20, noun_indices=5, adj_indices=2, edge_attr_len=20
# Graph 21: context nodes=63, edge_index_context.max()=62, dep nodes=63, edge_index_dep.max()=62, noun_indices=15, adj_indices=6, edge_attr_len=62
# Graph 22: context nodes=29, edge_index_context.max()=28, dep nodes=29, edge_index_dep.max()=28, noun_indices=9, adj_indices=5, edge_attr_len=28
# Graph 23: context nodes=81, edge_index_context.max()=80, dep nodes=81, edge_index_dep.max()=80, noun_indices=12, adj_indices=11, edge_attr_len=80
# Graph 24: context nodes=65, edge_index_context.max()=64, dep nodes=65, edge_index_dep.max()=64, noun_indices=12, adj_indices=4, edge_attr_len=64
# Graph 25: context nodes=47, edge_index_context.max()=46, dep nodes=47, edge_index_dep.max()=46, noun_indices=12, adj_indices=4, edge_attr_len=46
# Graph 26: context nodes=130, edge_index_context.max()=129, dep nodes=130, edge_index_dep.max()=129, noun_indices=24, adj_indices=9, edge_attr_len=129
# Graph 27: context nodes=173, edge_index_context.max()=172, dep nodes=173, edge_index_dep.max()=172, noun_indices=36, adj_indices=18, edge_attr_len=172
# Graph 28: context nodes=269, edge_index_context.max()=268, dep nodes=269, edge_index_dep.max()=268, noun_indices=42, adj_indices=22, edge_attr_len=266
# Graph 29: context nodes=45, edge_index_context.max()=44, dep nodes=45, edge_index_dep.max()=44, noun_indices=8, adj_indices=1, edge_attr_len=44
# Graph 30: context nodes=79, edge_index_context.max()=78, dep nodes=79, edge_index_dep.max()=78, noun_indices=15, adj_indices=12, edge_attr_len=78
# Graph 31: context nodes=63, edge_index_context.max()=62, dep nodes=63, edge_index_dep.max()=62, noun_indices=13, adj_indices=5, edge_attr_len=60
# Graph 32: context nodes=121, edge_index_context.max()=120, dep nodes=121, edge_index_dep.max()=120, noun_indices=25, adj_indices=10, edge_attr_len=119
# Graph 33: context nodes=47, edge_index_context.max()=46, dep nodes=47, edge_index_dep.max()=46, noun_indices=11, adj_indices=4, edge_attr_len=46
# Graph 34: context nodes=235, edge_index_context.max()=234, dep nodes=235, edge_index_dep.max()=234, noun_indices=36, adj_indices=17, edge_attr_len=231
# Graph 35: context nodes=156, edge_index_context.max()=155, dep nodes=156, edge_index_dep.max()=155, noun_indices=35, adj_indices=6, edge_attr_len=155
# Graph 36: context nodes=114, edge_index_context.max()=113, dep nodes=114, edge_index_dep.max()=113, noun_indices=19, adj_indices=12, edge_attr_len=112
# Graph 37: context nodes=70, edge_index_context.max()=69, dep nodes=70, edge_index_dep.max()=69, noun_indices=15, adj_indices=6, edge_attr_len=68
# Graph 38: context nodes=27, edge_index_context.max()=26, dep nodes=27, edge_index_dep.max()=26, noun_indices=4, adj_indices=3, edge_attr_len=26
# Graph 39: context nodes=411, edge_index_context.max()=410, dep nodes=411, edge_index_dep.max()=410, noun_indices=86, adj_indices=28, edge_attr_len=408
# Graph 40: context nodes=39, edge_index_context.max()=38, dep nodes=39, edge_index_dep.max()=38, noun_indices=8, adj_indices=3, edge_attr_len=38
# Graph 41: context nodes=163, edge_index_context.max()=162, dep nodes=163, edge_index_dep.max()=162, noun_indices=30, adj_indices=10, edge_attr_len=161
# Graph 42: context nodes=31, edge_index_context.max()=30, dep nodes=31, edge_index_dep.max()=30, noun_indices=8, adj_indices=6, edge_attr_len=29
# Graph 43: context nodes=54, edge_index_context.max()=53, dep nodes=54, edge_index_dep.max()=53, noun_indices=16, adj_indices=12, edge_attr_len=53
# Graph 44: context nodes=86, edge_index_context.max()=85, dep nodes=86, edge_index_dep.max()=85, noun_indices=14, adj_indices=13, edge_attr_len=84
# Graph 45: context nodes=313, edge_index_context.max()=312, dep nodes=313, edge_index_dep.max()=312, noun_indices=65, adj_indices=29, edge_attr_len=309
# Graph 46: context nodes=47, edge_index_context.max()=46, dep nodes=47, edge_index_dep.max()=46, noun_indices=10, adj_indices=5, edge_attr_len=46
# Graph 47: context nodes=26, edge_index_context.max()=25, dep nodes=26, edge_index_dep.max()=25, noun_indices=6, adj_indices=1, edge_attr_len=25
# Graph 48: context nodes=107, edge_index_context.max()=106, dep nodes=107, edge_index_dep.max()=106, noun_indices=16, adj_indices=10, edge_attr_len=106
# Graph 49: context nodes=204, edge_index_context.max()=203, dep nodes=204, edge_index_dep.max()=203, noun_indices=35, adj_indices=13, edge_attr_len=203
# Graph 50: context nodes=112, edge_index_context.max()=111, dep nodes=112, edge_index_dep.max()=111, noun_indices=17, adj_indices=12, edge_attr_len=111
# Graph 51: context nodes=97, edge_index_context.max()=96, dep nodes=97, edge_index_dep.max()=96, noun_indices=17, adj_indices=5, edge_attr_len=96
# Graph 52: context nodes=17, edge_index_context.max()=16, dep nodes=17, edge_index_dep.max()=16, noun_indices=3, adj_indices=4, edge_attr_len=16
# Graph 53: context nodes=59, edge_index_context.max()=58, dep nodes=59, edge_index_dep.max()=58, noun_indices=14, adj_indices=7, edge_attr_len=58
# Graph 54: context nodes=161, edge_index_context.max()=160, dep nodes=161, edge_index_dep.max()=160, noun_indices=35, adj_indices=12, edge_attr_len=159
# Graph 55: context nodes=33, edge_index_context.max()=32, dep nodes=33, edge_index_dep.max()=32, noun_indices=7, adj_indices=3, edge_attr_len=32
# Graph 56: context nodes=51, edge_index_context.max()=50, dep nodes=51, edge_index_dep.max()=50, noun_indices=12, adj_indices=5, edge_attr_len=50
# Graph 57: context nodes=65, edge_index_context.max()=64, dep nodes=65, edge_index_dep.max()=64, noun_indices=10, adj_indices=3, edge_attr_len=63
# Graph 58: context nodes=41, edge_index_context.max()=40, dep nodes=41, edge_index_dep.max()=40, noun_indices=10, adj_indices=5, edge_attr_len=39
# Graph 59: context nodes=77, edge_index_context.max()=76, dep nodes=77, edge_index_dep.max()=76, noun_indices=17, adj_indices=5, edge_attr_len=75
# Graph 60: context nodes=67, edge_index_context.max()=66, dep nodes=67, edge_index_dep.max()=66, noun_indices=16, adj_indices=4, edge_attr_len=65
# Graph 61: context nodes=64, edge_index_context.max()=63, dep nodes=64, edge_index_dep.max()=63, noun_indices=9, adj_indices=7, edge_attr_len=61
# Graph 62: context nodes=84, edge_index_context.max()=83, dep nodes=84, edge_index_dep.max()=83, noun_indices=21, adj_indices=7, edge_attr_len=82
# Graph 63: context nodes=168, edge_index_context.max()=167, dep nodes=168, edge_index_dep.max()=167, noun_indices=33, adj_indices=16, edge_attr_len=165
# Graph 64: context nodes=177, edge_index_context.max()=176, dep nodes=177, edge_index_dep.max()=176, noun_indices=28, adj_indices=8, edge_attr_len=173
# Graph 65: context nodes=146, edge_index_context.max()=145, dep nodes=146, edge_index_dep.max()=145, noun_indices=20, adj_indices=12, edge_attr_len=145
# Graph 66: context nodes=132, edge_index_context.max()=131, dep nodes=132, edge_index_dep.max()=131, noun_indices=31, adj_indices=9, edge_attr_len=130
# Graph 67: context nodes=82, edge_index_context.max()=81, dep nodes=82, edge_index_dep.max()=81, noun_indices=11, adj_indices=7, edge_attr_len=81
# Graph 68: context nodes=98, edge_index_context.max()=97, dep nodes=98, edge_index_dep.max()=97, noun_indices=17, adj_indices=4, edge_attr_len=94
# Graph 69: context nodes=420, edge_index_context.max()=419, dep nodes=420, edge_index_dep.max()=419, noun_indices=77, adj_indices=31, edge_attr_len=416
# Graph 70: context nodes=25, edge_index_context.max()=24, dep nodes=25, edge_index_dep.max()=24, noun_indices=8, adj_indices=5, edge_attr_len=24
# Graph 71: context nodes=114, edge_index_context.max()=113, dep nodes=114, edge_index_dep.max()=113, noun_indices=25, adj_indices=12, edge_attr_len=113
# Graph 72: context nodes=510, edge_index_context.max()=509, dep nodes=510, edge_index_dep.max()=509, noun_indices=88, adj_indices=41, edge_attr_len=503
# Graph 73: context nodes=60, edge_index_context.max()=59, dep nodes=60, edge_index_dep.max()=59, noun_indices=7, adj_indices=8, edge_attr_len=58
# Graph 74: context nodes=66, edge_index_context.max()=65, dep nodes=66, edge_index_dep.max()=65, noun_indices=10, adj_indices=10, edge_attr_len=64
# Graph 75: context nodes=46, edge_index_context.max()=45, dep nodes=46, edge_index_dep.max()=45, noun_indices=10, adj_indices=4, edge_attr_len=45
# Graph 76: context nodes=145, edge_index_context.max()=144, dep nodes=145, edge_index_dep.max()=144, noun_indices=32, adj_indices=20, edge_attr_len=144
# Graph 77: context nodes=89, edge_index_context.max()=88, dep nodes=89, edge_index_dep.max()=88, noun_indices=15, adj_indices=4, edge_attr_len=87
# Graph 78: context nodes=61, edge_index_context.max()=60, dep nodes=61, edge_index_dep.max()=60, noun_indices=15, adj_indices=7, edge_attr_len=60
# Graph 79: context nodes=213, edge_index_context.max()=212, dep nodes=213, edge_index_dep.max()=212, noun_indices=45, adj_indices=14, edge_attr_len=212
# Graph 80: context nodes=47, edge_index_context.max()=46, dep nodes=47, edge_index_dep.max()=46, noun_indices=9, adj_indices=5, edge_attr_len=46
# Graph 81: context nodes=114, edge_index_context.max()=113, dep nodes=114, edge_index_dep.max()=113, noun_indices=24, adj_indices=16, edge_attr_len=112
# Graph 82: context nodes=261, edge_index_context.max()=260, dep nodes=261, edge_index_dep.max()=260, noun_indices=52, adj_indices=31, edge_attr_len=259
# Graph 83: context nodes=52, edge_index_context.max()=51, dep nodes=52, edge_index_dep.max()=51, noun_indices=16, adj_indices=1, edge_attr_len=51
# Graph 84: context nodes=15, edge_index_context.max()=14, dep nodes=15, edge_index_dep.max()=14, noun_indices=2, adj_indices=2, edge_attr_len=14
# Graph 85: context nodes=47, edge_index_context.max()=46, dep nodes=47, edge_index_dep.max()=46, noun_indices=9, adj_indices=6, edge_attr_len=46
# Graph 86: context nodes=30, edge_index_context.max()=29, dep nodes=30, edge_index_dep.max()=29, noun_indices=9, adj_indices=4, edge_attr_len=29
# Graph 87: context nodes=46, edge_index_context.max()=45, dep nodes=46, edge_index_dep.max()=45, noun_indices=9, adj_indices=5, edge_attr_len=45
# Graph 88: context nodes=105, edge_index_context.max()=104, dep nodes=105, edge_index_dep.max()=104, noun_indices=20, adj_indices=11, edge_attr_len=104
# Graph 89: context nodes=47, edge_index_context.max()=46, dep nodes=47, edge_index_dep.max()=46, noun_indices=10, adj_indices=10, edge_attr_len=46
# Graph 90: context nodes=58, edge_index_context.max()=57, dep nodes=58, edge_index_dep.max()=57, noun_indices=15, adj_indices=7, edge_attr_len=57
# Graph 91: context nodes=144, edge_index_context.max()=143, dep nodes=144, edge_index_dep.max()=143, noun_indices=28, adj_indices=16, edge_attr_len=142
# Graph 92: context nodes=175, edge_index_context.max()=174, dep nodes=175, edge_index_dep.max()=174, noun_indices=26, adj_indices=18, edge_attr_len=173
# Graph 93: context nodes=82, edge_index_context.max()=81, dep nodes=82, edge_index_dep.max()=81, noun_indices=16, adj_indices=10, edge_attr_len=81
# Graph 94: context nodes=47, edge_index_context.max()=46, dep nodes=47, edge_index_dep.max()=46, noun_indices=6, adj_indices=4, edge_attr_len=45
# Graph 95: context nodes=63, edge_index_context.max()=62, dep nodes=63, edge_index_dep.max()=62, noun_indices=10, adj_indices=9, edge_attr_len=62
# Graph 96: context nodes=53, edge_index_context.max()=52, dep nodes=53, edge_index_dep.max()=52, noun_indices=17, adj_indices=9, edge_attr_len=52
# Graph 97: context nodes=29, edge_index_context.max()=28, dep nodes=29, edge_index_dep.max()=28, noun_indices=4, adj_indices=3, edge_attr_len=28
# Graph 98: context nodes=163, edge_index_context.max()=162, dep nodes=163, edge_index_dep.max()=162, noun_indices=30, adj_indices=15, edge_attr_len=161
# Graph 99: context nodes=31, edge_index_context.max()=30, dep nodes=31, edge_index_dep.max()=30, noun_indices=5, adj_indices=5, edge_attr_len=30
# Graph 100: context nodes=119, edge_index_context.max()=118, dep nodes=119, edge_index_dep.max()=118, noun_indices=21, adj_indices=6, edge_attr_len=118
# Graph 101: context nodes=46, edge_index_context.max()=45, dep nodes=46, edge_index_dep.max()=45, noun_indices=12, adj_indices=7, edge_attr_len=45
# Graph 102: context nodes=33, edge_index_context.max()=32, dep nodes=33, edge_index_dep.max()=32, noun_indices=4, adj_indices=7, edge_attr_len=32
# Graph 103: context nodes=19, edge_index_context.max()=18, dep nodes=19, edge_index_dep.max()=18, noun_indices=3, adj_indices=1, edge_attr_len=18
# Graph 104: context nodes=39, edge_index_context.max()=38, dep nodes=39, edge_index_dep.max()=38, noun_indices=7, adj_indices=6, edge_attr_len=37
# Graph 105: context nodes=61, edge_index_context.max()=60, dep nodes=61, edge_index_dep.max()=60, noun_indices=10, adj_indices=7, edge_attr_len=60
# Graph 106: context nodes=29, edge_index_context.max()=28, dep nodes=29, edge_index_dep.max()=28, noun_indices=6, adj_indices=4, edge_attr_len=28
# Graph 107: context nodes=32, edge_index_context.max()=31, dep nodes=32, edge_index_dep.max()=31, noun_indices=8, adj_indices=5, edge_attr_len=31
# Graph 108: context nodes=100, edge_index_context.max()=99, dep nodes=100, edge_index_dep.max()=99, noun_indices=24, adj_indices=5, edge_attr_len=98
# Graph 109: context nodes=32, edge_index_context.max()=31, dep nodes=32, edge_index_dep.max()=31, noun_indices=6, adj_indices=4, edge_attr_len=31
# Graph 110: context nodes=38, edge_index_context.max()=37, dep nodes=38, edge_index_dep.max()=37, noun_indices=5, adj_indices=6, edge_attr_len=37
# Graph 111: context nodes=68, edge_index_context.max()=67, dep nodes=68, edge_index_dep.max()=67, noun_indices=15, adj_indices=11, edge_attr_len=67
# Graph 112: context nodes=22, edge_index_context.max()=21, dep nodes=22, edge_index_dep.max()=21, noun_indices=6, adj_indices=2, edge_attr_len=21
# Graph 113: context nodes=233, edge_index_context.max()=232, dep nodes=233, edge_index_dep.max()=232, noun_indices=40, adj_indices=28, edge_attr_len=232
# ...
# Graph 94: context nodes=112, edge_index_context.max()=111, dep nodes=112, edge_index_dep.max()=111, noun_indices=17, adj_indices=12, edge_attr_len=111
# Graph 95: context nodes=41, edge_index_context.max()=40, dep nodes=41, edge_index_dep.max()=40, noun_indices=10, adj_indices=3, edge_attr_len=40
# Graph 96: context nodes=28, edge_index_context.max()=27, dep nodes=28, edge_index_dep.max()=27, noun_indices=5, adj_indices=2, edge_attr_len=27
# Graph 97: context nodes=171, edge_index_context.max()=170, dep nodes=171, edge_index_dep.max()=170, noun_indices=29, adj_indices=11, edge_attr_len=170
# Graph 98: context nodes=95, edge_index_context.max()=94, dep nodes=95, edge_index_dep.max()=94, noun_indices=21, adj_indices=6, edge_attr_len=94
# Graph 99: context nodes=145, edge_index_context.max()=144, dep nodes=145, edge_index_dep.max()=144, noun_indices=32, adj_indices=20, edge_attr_len=144
# Graph 100: context nodes=47, edge_index_context.max()=46, dep nodes=47, edge_index_dep.max()=46, noun_indices=10, adj_indices=5, edge_attr_len=46
# Graph 101: context nodes=22, edge_index_context.max()=21, dep nodes=22, edge_index_dep.max()=21, noun_indices=6, adj_indices=2, edge_attr_len=21
# Graph 102: context nodes=200, edge_index_context.max()=199, dep nodes=200, edge_index_dep.max()=199, noun_indices=38, adj_indices=11, edge_attr_len=199
# Graph 103: context nodes=67, edge_index_context.max()=66, dep nodes=67, edge_index_dep.max()=66, noun_indices=16, adj_indices=4, edge_attr_len=65
# Graph 104: context nodes=40, edge_index_context.max()=39, dep nodes=40, edge_index_dep.max()=39, noun_indices=8, adj_indices=6, edge_attr_len=39
# Graph 105: context nodes=36, edge_index_context.max()=35, dep nodes=36, edge_index_dep.max()=35, noun_indices=7, adj_indices=5, edge_attr_len=35
# Graph 106: context nodes=66, edge_index_context.max()=65, dep nodes=66, edge_index_dep.max()=65, noun_indices=10, adj_indices=10, edge_attr_len=64
# Graph 107: context nodes=40, edge_index_context.max()=39, dep nodes=40, edge_index_dep.max()=39, noun_indices=10, adj_indices=6, edge_attr_len=39
# Graph 108: context nodes=15, edge_index_context.max()=14, dep nodes=15, edge_index_dep.max()=14, noun_indices=2, adj_indices=2, edge_attr_len=14
# Graph 109: context nodes=46, edge_index_context.max()=45, dep nodes=46, edge_index_dep.max()=45, noun_indices=9, adj_indices=5, edge_attr_len=45
# Graph 110: context nodes=52, edge_index_context.max()=51, dep nodes=52, edge_index_dep.max()=51, noun_indices=16, adj_indices=1, edge_attr_len=51
# Graph 111: context nodes=63, edge_index_context.max()=62, dep nodes=63, edge_index_dep.max()=62, noun_indices=13, adj_indices=5, edge_attr_len=60
# Graph 112: context nodes=130, edge_index_context.max()=129, dep nodes=130, edge_index_dep.max()=129, noun_indices=24, adj_indices=9, edge_attr_len=129
# Graph 113: context nodes=70, edge_index_context.max()=69, dep nodes=70, edge_index_dep.max()=69, noun_indices=9, adj_indices=11, edge_attr_len=69
# Graph 114: context nodes=313, edge_index_context.max()=312, dep nodes=313, edge_index_dep.max()=312, noun_indices=65, adj_indices=29, edge_attr_len=309
# Graph 115: context nodes=63, edge_index_context.max()=62, dep nodes=63, edge_index_dep.max()=62, noun_indices=13, adj_indices=9, edge_attr_len=62
# Graph 116: context nodes=100, edge_index_context.max()=99, dep nodes=100, edge_index_dep.max()=99, noun_indices=24, adj_indices=5, edge_attr_len=98
# Graph 117: context nodes=118, edge_index_context.max()=117, dep nodes=118, edge_index_dep.max()=117, noun_indices=16, adj_indices=6, edge_attr_len=115
# Graph 118: context nodes=60, edge_index_context.max()=59, dep nodes=60, edge_index_dep.max()=59, noun_indices=7, adj_indices=8, edge_attr_len=58
# Graph 119: context nodes=36, edge_index_context.max()=35, dep nodes=36, edge_index_dep.max()=35, noun_indices=6, adj_indices=4, edge_attr_len=33
# Graph 120: context nodes=27, edge_index_context.max()=26, dep nodes=27, edge_index_dep.max()=26, noun_indices=5, adj_indices=3, edge_attr_len=26
# Graph 121: context nodes=39, edge_index_context.max()=38, dep nodes=39, edge_index_dep.max()=38, noun_indices=8, adj_indices=3, edge_attr_len=38
# Graph 122: context nodes=204, edge_index_context.max()=203, dep nodes=204, edge_index_dep.max()=203, noun_indices=35, adj_indices=13, edge_attr_len=203
# Graph 123: context nodes=149, edge_index_context.max()=148, dep nodes=149, edge_index_dep.max()=148, noun_indices=28, adj_indices=9, edge_attr_len=148
# Graph 124: context nodes=41, edge_index_context.max()=40, dep nodes=41, edge_index_dep.max()=40, noun_indices=10, adj_indices=5, edge_attr_len=39
# Graph 125: context nodes=99, edge_index_context.max()=98, dep nodes=99, edge_index_dep.max()=98, noun_indices=20, adj_indices=9, edge_attr_len=98
# Graph 126: context nodes=65, edge_index_context.max()=64, dep nodes=65, edge_index_dep.max()=64, noun_indices=10, adj_indices=3, edge_attr_len=63
# Graph 127: context nodes=213, edge_index_context.max()=212, dep nodes=213, edge_index_dep.max()=212, noun_indices=45, adj_indices=14, edge_attr_len=212
# Graph 128: context nodes=38, edge_index_context.max()=37, dep nodes=38, edge_index_dep.max()=37, noun_indices=5, adj_indices=6, edge_attr_len=37
# Graph 129: context nodes=135, edge_index_context.max()=134, dep nodes=135, edge_index_dep.max()=134, noun_indices=23, adj_indices=15, edge_attr_len=133
# Graph 130: context nodes=108, edge_index_context.max()=107, dep nodes=108, edge_index_dep.max()=107, noun_indices=19, adj_indices=10, edge_attr_len=107
# Graph 131: context nodes=79, edge_index_context.max()=78, dep nodes=79, edge_index_dep.max()=78, noun_indices=15, adj_indices=12, edge_attr_len=78
# Graph 132: context nodes=216, edge_index_context.max()=215, dep nodes=216, edge_index_dep.max()=215, noun_indices=38, adj_indices=18, edge_attr_len=214
# Graph 133: context nodes=155, edge_index_context.max()=154, dep nodes=155, edge_index_dep.max()=154, noun_indices=28, adj_indices=9, edge_attr_len=154
# Graph 134: context nodes=98, edge_index_context.max()=97, dep nodes=98, edge_index_dep.max()=97, noun_indices=17, adj_indices=4, edge_attr_len=94
# Graph 135: context nodes=94, edge_index_context.max()=93, dep nodes=94, edge_index_dep.max()=93, noun_indices=6, adj_indices=9, edge_attr_len=90
# Graph 136: context nodes=60, edge_index_context.max()=59, dep nodes=60, edge_index_dep.max()=59, noun_indices=9, adj_indices=4, edge_attr_len=56
# Graph 137: context nodes=156, edge_index_context.max()=155, dep nodes=156, edge_index_dep.max()=155, noun_indices=35, adj_indices=6, edge_attr_len=155
# Graph 138: context nodes=262, edge_index_context.max()=261, dep nodes=262, edge_index_dep.max()=261, noun_indices=40, adj_indices=22, edge_attr_len=258
# Graph 139: context nodes=99, edge_index_context.max()=98, dep nodes=99, edge_index_dep.max()=98, noun_indices=19, adj_indices=10, edge_attr_len=98
# Graph 140: context nodes=19, edge_index_context.max()=18, dep nodes=19, edge_index_dep.max()=18, noun_indices=4, adj_indices=3, edge_attr_len=18
# Graph 141: context nodes=78, edge_index_context.max()=77, dep nodes=78, edge_index_dep.max()=77, noun_indices=15, adj_indices=9, edge_attr_len=76
# Graph 142: context nodes=138, edge_index_context.max()=137, dep nodes=138, edge_index_dep.max()=137, noun_indices=29, adj_indices=13, edge_attr_len=134
# Graph 143: context nodes=27, edge_index_context.max()=26, dep nodes=27, edge_index_dep.max()=26, noun_indices=4, adj_indices=3, edge_attr_len=26
# Graph 144: context nodes=256, edge_index_context.max()=255, dep nodes=256, edge_index_dep.max()=255, noun_indices=52, adj_indices=20, edge_attr_len=251
# Graph 145: context nodes=39, edge_index_context.max()=38, dep nodes=39, edge_index_dep.max()=38, noun_indices=4, adj_indices=6, edge_attr_len=38
# Graph 146: context nodes=117, edge_index_context.max()=116, dep nodes=117, edge_index_dep.max()=116, noun_indices=20, adj_indices=8, edge_attr_len=116
# Graph 147: context nodes=36, edge_index_context.max()=35, dep nodes=36, edge_index_dep.max()=35, noun_indices=9, adj_indices=3, edge_attr_len=35
# Graph 148: context nodes=31, edge_index_context.max()=30, dep nodes=31, edge_index_dep.max()=30, noun_indices=8, adj_indices=6, edge_attr_len=29
# Graph 149: context nodes=37, edge_index_context.max()=36, dep nodes=37, edge_index_dep.max()=36, noun_indices=6, adj_indices=4, edge_attr_len=36
# Graph 150: context nodes=175, edge_index_context.max()=174, dep nodes=175, edge_index_dep.max()=174, noun_indices=26, adj_indices=18, edge_attr_len=173
# Graph 151: context nodes=86, edge_index_context.max()=85, dep nodes=86, edge_index_dep.max()=85, noun_indices=14, adj_indices=13, edge_attr_len=84
# Graph 152: context nodes=269, edge_index_context.max()=268, dep nodes=269, edge_index_dep.max()=268, noun_indices=42, adj_indices=22, edge_attr_len=266
# Graph 153: context nodes=71, edge_index_context.max()=70, dep nodes=71, edge_index_dep.max()=70, noun_indices=16, adj_indices=9, edge_attr_len=70
# Graph 154: context nodes=21, edge_index_context.max()=20, dep nodes=21, edge_index_dep.max()=20, noun_indices=6, adj_indices=5, edge_attr_len=20
# Graph 155: context nodes=106, edge_index_context.max()=105, dep nodes=106, edge_index_dep.max()=105, noun_indices=24, adj_indices=8, edge_attr_len=105
# Graph 156: context nodes=29, edge_index_context.max()=28, dep nodes=29, edge_index_dep.max()=28, noun_indices=11, adj_indices=3, edge_attr_len=28
# Graph 157: context nodes=67, edge_index_context.max()=66, dep nodes=67, edge_index_dep.max()=66, noun_indices=12, adj_indices=5, edge_attr_len=64
# Graph 158: context nodes=71, edge_index_context.max()=70, dep nodes=71, edge_index_dep.max()=70, noun_indices=13, adj_indices=9, edge_attr_len=70
# Graph 159: context nodes=102, edge_index_context.max()=101, dep nodes=102, edge_index_dep.max()=101, noun_indices=21, adj_indices=10, edge_attr_len=97
# Graph 160: context nodes=84, edge_index_context.max()=83, dep nodes=84, edge_index_dep.max()=83, noun_indices=21, adj_indices=7, edge_attr_len=82
# Graph 161: context nodes=65, edge_index_context.max()=64, dep nodes=65, edge_index_dep.max()=64, noun_indices=9, adj_indices=7, edge_attr_len=64
# Graph 162: context nodes=53, edge_index_context.max()=52, dep nodes=53, edge_index_dep.max()=52, noun_indices=17, adj_indices=9, edge_attr_len=52
# Graph 163: context nodes=120, edge_index_context.max()=119, dep nodes=120, edge_index_dep.max()=119, noun_indices=21, adj_indices=12, edge_attr_len=115
# Graph 164: context nodes=33, edge_index_context.max()=32, dep nodes=33, edge_index_dep.max()=32, noun_indices=4, adj_indices=7, edge_attr_len=32
# Graph 165: context nodes=84, edge_index_context.max()=83, dep nodes=84, edge_index_dep.max()=83, noun_indices=17, adj_indices=7, edge_attr_len=81
# Graph 166: context nodes=29, edge_index_context.max()=28, dep nodes=29, edge_index_dep.max()=28, noun_indices=4, adj_indices=3, edge_attr_len=28
# Graph 167: context nodes=52, edge_index_context.max()=51, dep nodes=52, edge_index_dep.max()=51, noun_indices=18, adj_indices=7, edge_attr_len=51
# Graph 168: context nodes=27, edge_index_context.max()=26, dep nodes=27, edge_index_dep.max()=26, noun_indices=7, adj_indices=6, edge_attr_len=26
# Graph 169: context nodes=32, edge_index_context.max()=31, dep nodes=32, edge_index_dep.max()=31, noun_indices=6, adj_indices=4, edge_attr_len=31
# Graph 170: context nodes=45, edge_index_context.max()=44, dep nodes=45, edge_index_dep.max()=44, noun_indices=8, adj_indices=1, edge_attr_len=44
# Graph 171: context nodes=77, edge_index_context.max()=76, dep nodes=77, edge_index_dep.max()=76, noun_indices=17, adj_indices=6, edge_attr_len=76
# Graph 172: context nodes=146, edge_index_context.max()=145, dep nodes=146, edge_index_dep.max()=145, noun_indices=20, adj_indices=12, edge_attr_len=145
# Graph 173: context nodes=21, edge_index_context.max()=20, dep nodes=21, edge_index_dep.max()=20, noun_indices=4, adj_indices=3, edge_attr_len=20
# Graph 174: context nodes=109, edge_index_context.max()=108, dep nodes=109, edge_index_dep.max()=108, noun_indices=20, adj_indices=9, edge_attr_len=108
# Graph 175: context nodes=113, edge_index_context.max()=112, dep nodes=113, edge_index_dep.max()=112, noun_indices=22, adj_indices=7, edge_attr_len=112
# Graph 176: context nodes=30, edge_index_context.max()=29, dep nodes=30, edge_index_dep.max()=29, noun_indices=9, adj_indices=4, edge_attr_len=29
# Graph 177: context nodes=26, edge_index_context.max()=25, dep nodes=26, edge_index_dep.max()=25, noun_indices=5, adj_indices=3, edge_attr_len=25
# Graph 178: context nodes=89, edge_index_context.max()=88, dep nodes=89, edge_index_dep.max()=88, noun_indices=17, adj_indices=11, edge_attr_len=88
# Graph 179: context nodes=163, edge_index_context.max()=162, dep nodes=163, edge_index_dep.max()=162, noun_indices=30, adj_indices=15, edge_attr_len=161
# Graph 180: context nodes=70, edge_index_context.max()=69, dep nodes=70, edge_index_dep.max()=69, noun_indices=15, adj_indices=6, edge_attr_len=68
# Graph 181: context nodes=161, edge_index_context.max()=160, dep nodes=161, edge_index_dep.max()=160, noun_indices=26, adj_indices=15, edge_attr_len=159
# Graph 182: context nodes=52, edge_index_context.max()=51, dep nodes=52, edge_index_dep.max()=51, noun_indices=12, adj_indices=6, edge_attr_len=51
# Graph 183: context nodes=121, edge_index_context.max()=120, dep nodes=121, edge_index_dep.max()=120, noun_indices=29, adj_indices=10, edge_attr_len=120
# Graph 184: context nodes=63, edge_index_context.max()=62, dep nodes=63, edge_index_dep.max()=62, noun_indices=15, adj_indices=6, edge_attr_len=62
# Graph 185: context nodes=73, edge_index_context.max()=72, dep nodes=73, edge_index_dep.max()=72, noun_indices=11, adj_indices=7, edge_attr_len=72
# Graph 186: context nodes=348, edge_index_context.max()=347, dep nodes=348, edge_index_dep.max()=347, noun_indices=53, adj_indices=19, edge_attr_len=345
# Graph 187: context nodes=47, edge_index_context.max()=46, dep nodes=47, edge_index_dep.max()=46, noun_indices=10, adj_indices=10, edge_attr_len=46
# Graph 188: context nodes=76, edge_index_context.max()=75, dep nodes=76, edge_index_dep.max()=75, noun_indices=9, adj_indices=5, edge_attr_len=74
# Graph 189: context nodes=60, edge_index_context.max()=59, dep nodes=60, edge_index_dep.max()=59, noun_indices=14, adj_indices=4, edge_attr_len=59
# Graph 190: context nodes=30, edge_index_context.max()=29, dep nodes=30, edge_index_dep.max()=29, noun_indices=5, adj_indices=4, edge_attr_len=29
# Graph 191: context nodes=29, edge_index_context.max()=28, dep nodes=29, edge_index_dep.max()=28, noun_indices=6, adj_indices=4, edge_attr_len=28
# Graph 192: context nodes=235, edge_index_context.max()=234, dep nodes=235, edge_index_dep.max()=234, noun_indices=36, adj_indices=17, edge_attr_len=231
# Graph 193: context nodes=163, edge_index_context.max()=162, dep nodes=163, edge_index_dep.max()=162, noun_indices=30, adj_indices=10, edge_attr_len=161
# Graph 194: context nodes=183, edge_index_context.max()=182, dep nodes=183, edge_index_dep.max()=182, noun_indices=30, adj_indices=18, edge_attr_len=181
# `Trainer.fit` stopped: `max_epochs=10` reached.
# Graph 195: context nodes=198, edge_index_context.max()=197, dep nodes=198, edge_index_dep.max()=197, noun_indices=44, adj_indices=20, edge_attr_len=193
# Graph 196: context nodes=103, edge_index_context.max()=102, dep nodes=103, edge_index_dep.max()=102, noun_indices=27, adj_indices=13, edge_attr_len=101
# Graph 197: context nodes=94, edge_index_context.max()=93, dep nodes=94, edge_index_dep.max()=93, noun_indices=14, adj_indices=9, edge_attr_len=92
# Graph 198: context nodes=61, edge_index_context.max()=60, dep nodes=61, edge_index_dep.max()=60, noun_indices=15, adj_indices=7, edge_attr_len=60
# Graph 199: context nodes=64, edge_index_context.max()=63, dep nodes=64, edge_index_dep.max()=63, noun_indices=9, adj_indices=7, edge_attr_len=61
# Epoch 9 - Train Loss: 3.2521653175354004, Node Loss: 0.04769982770085335, Edge Loss: 3.2044663429260254
# Pre-training completed. Checkpoint saved at: data/pretrained_final.ckpt
